# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import timeit
import random
import time

# import citipy module
from citipy import citipy

# import requests library
import requests

# import api key
from config import weather_api_key

# open weather map starter url and api key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# import datetime module
from datetime import datetime

# %% [markdown]
# # Create a new set of 2,000 random latitudes and longitudes

# %%
# Create set of 2000 random lat/lng combos
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# # Get the nearest city using the citipy module

# %%
# Create list for holding cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
# cities list
cities
# Out:
# ['taolanaro',
#  'kargasok',
#  'ushuaia',
#  'iqaluit',
#  'barentsburg',
#  'ahipara',
#  'hobyo',
#  'saint-philippe',
#  'isangel',
#  'east london',
#  'punta arenas',
#  'bubaque',
#  'kawhia',
#  'busselton',
#  'xining',
#  'villa bruzual',
#  'half moon bay',
#  'port alfred',
#  'vaini',
#  'galle',
#  'jamestown',
#  'srednekolymsk',
#  'meulaboh',
#  'victoria',
#  'atuona',
#  'klaksvik',
#  'port blair',
#  'rikitea',
#  'mildura',
#  'kerki',
#  'barrow',
#  'new norfolk',
#  'kapaa',
#  'evensk',
#  'qaanaaq',
#  'mys shmidta',
#  'maraa',
#  'tuktoyaktuk',
#  'aleksandrovka',
#  'ust-kuyga',
#  'saskylakh',
#  'bethel',
#  'cape town',
#  'arraial do cabo',
#  'jalu',
#  'mataura',
#  'luba',
#  'ponta do sol',
#  'grindavik',
#  'kirensk',
#  'nizhneyansk',
#  'marsh harbour',
#  'hermanus',
#  'alofi',
#  'yumen',
#  'abu dhabi',
#  'chulman',
#  'tabuk',
#  'lavrentiya',
#  'aklavik',
#  'illoqqortoormiut',
#  'esperance',
#  'zhigansk',
#  'faya',
#  'kassala',
#  'salinas',
#  'dikson',
#  'temaraia',
#  'ixtapa',
#  'plettenberg bay',
#  'chokurdakh',
#  'codrington',
#  'puerto ayora',
#  'kuytun',
#  'innisfail',
#  'honiara',
#  'mount isa',
#  'port elizabeth',
#  'bredasdorp',
#  'yelizovo',
#  'malinovoye ozero',
#  'avarua',
#  'ilkal',
#  'nikolskoye',
#  'georgetown',
#  'bluff',
#  'lebu',
#  'casper',
#  'salym',
#  'pangnirtung',
#  'cervo',
#  'seymchan',
#  'pevek',
#  'ha giang',
#  'karpathos',
#  'baculin',
#  'albany',
#  'hithadhoo',
#  'zabinka',
#  'butaritari',
#  'yellowknife',
#  'poros',
#  'comodoro rivadavia',
#  'marsa matruh',
#  'karasjok',
#  'touros',
#  'nouadhibou',
#  'guerrero negro',
#  'portland',
#  'mar del plata',
#  'mocambique',
#  'finschhafen',
#  'sao filipe',
#  'santiago',
#  'khatanga',
#  'rungata',
#  'hofn',
#  'pochutla',
#  'linchuan',
#  'bengkulu',
#  'fortuna',
#  'saint-augustin',
#  'qandala',
#  'alyangula',
#  'kaliua',
#  'thompson',
#  'hobart',
#  'saldanha',
#  'saint-francois',
#  'manitouwadge',
#  'hambantota',
#  'hovd',
#  'hilo',
#  'nichinan',
#  'acoua',
#  'port moresby',
#  'saint george',
#  'megion',
#  'cockburn town',
#  'lasa',
#  'sisimiut',
#  'vieques',
#  'clyde river',
#  'kodiak',
#  'fairbanks',
#  'blenheim',
#  'waingapu',
#  'rocha',
#  'pietarsaari',
#  'talnakh',
#  'boa vista',
#  'vryburg',
#  'kruisfontein',
#  'harbour breton',
#  'kelc',
#  'arandis',
#  'lorengau',
#  'tsihombe',
#  'mamallapuram',
#  'upernavik',
#  'axim',
#  'romny',
#  'taseyevo',
#  'dingle',
#  'los llanos de aridane',
#  'port macquarie',
#  'ribeira grande',
#  'kizukuri',
#  'eirunepe',
#  'tenkodogo',
#  'kawalu',
#  'amderma',
#  'cabo san lucas',
#  'yamada',
#  'suez',
#  'leningradskiy',
#  'gannan',
#  'turukhansk',
#  'craig',
#  'yar-sale',
#  'lolua',
#  'kudahuvadhoo',
#  'gat',
#  'zonguldak',
#  'cheuskiny',
#  'chernyshevskiy',
#  'soyo',
#  'flinders',
#  'yuncheng',
#  'pilot butte',
#  'illela',
#  'havelock',
#  'requena',
#  'virovitica',
#  'birecik',
#  'setermoen',
#  'mayo',
#  'sao joao da barra',
#  'kaitangata',
#  'kloulklubed',
#  'mehamn',
#  'grand river south east',
#  'moussoro',
#  'port-gentil',
#  'tumannyy',
#  'aktau',
#  'khoy',
#  'tuggurt',
#  'ust-omchug',
#  'college',
#  'bandarbeyla',
#  'imeni zhelyabova',
#  'cueramaro',
#  'chuy',
#  'ossora',
#  'aktas',
#  'longyearbyen',
#  'praia da vitoria',
#  'gurupa',
#  'yatou',
#  'port lincoln',
#  'laguna',
#  'luderitz',
#  'provideniya',
#  'banda aceh',
#  'teya',
#  'stromness',
#  'geraldton',
#  'katsuura',
#  'bambous virieux',
#  'torbay',
#  'svetlogorsk',
#  'huarmey',
#  'samusu',
#  'mahebourg',
#  'vardo',
#  'faxinal',
#  'tasiilaq',
#  'segezha',
#  'pizarro',
#  'ferrandina',
#  'kodinsk',
#  'dwarka',
#  'anadyr',
#  'svetlaya',
#  'rawson',
#  'coquimbo',
#  'quatre cocos',
#  'vaitupu',
#  'grand-santi',
#  'tiksi',
#  'khandyga',
#  'airai',
#  'abnub',
#  'south river',
#  'goderich',
#  'saint anthony',
#  'ilulissat',
#  'springbok',
#  'natitingou',
#  'matara',
#  'sitka',
#  'shenjiamen',
#  'taft',
#  'caravelas',
#  'micomeseng',
#  'belushya guba',
#  'okhotsk',
#  'tomatlan',
#  'mitsamiouli',
#  'ust-ilimsk',
#  'la ronge',
#  'khorixas',
#  'muncar',
#  'jacmel',
#  'severo-kurilsk',
#  'pucallpa',
#  'basco',
#  'nekrasovka',
#  'norman wells',
#  'attawapiskat',
#  'safaga',
#  'muriwai beach',
#  'auki',
#  'hirara',
#  'sarai alamgir',
#  'mascota',
#  'wareham',
#  'kemijarvi',
#  'mont-dore',
#  'muyezerskiy',
#  'batagay-alyta',
#  'tuatapere',
#  'sao felix do xingu',
#  'haimen',
#  'dalbandin',
#  'padang',
#  'carnarvon',
#  'nanortalik',
#  'copiapo',
#  'leshukonskoye',
#  'makung',
#  'himora',
#  'karaul',
#  'sorland',
#  'bosaso',
#  'takoradi',
#  'mareeba',
#  'bambanglipuro',
#  'kalawit',
#  'maputo',
#  'san quintin',
#  'hasaki',
#  'aquiraz',
#  'faanui',
#  'candawaga',
#  'careiro da varzea',
#  'maceio',
#  'arica',
#  'vila franca do campo',
#  'noumea',
#  'margate',
#  'seoul',
#  'sorvag',
#  'pimenta bueno',
#  'chengde',
#  'boffa',
#  'sanchazi',
#  'sovetskiy',
#  'kang',
#  'arlit',
#  'samarai',
#  'san cristobal',
#  'lamesa',
#  'vao',
#  'tautira',
#  'taoudenni',
#  'natal',
#  'souillac',
#  'fare',
#  'lompoc',
#  'ancud',
#  'msowero',
#  'ndende',
#  'karoi',
#  'kochki',
#  'galveston',
#  'tilichiki',
#  'sogdiondon',
#  'puri',
#  'santa cruz',
#  'belyy yar',
#  'hadishahr',
#  'hami',
#  'pimentel',
#  'mogocha',
#  'puerto colombia',
#  'nabire',
#  'castro',
#  'inhambane',
#  'sarangani',
#  'maragogi',
#  'lokosovo',
#  'batagay',
#  'wamba',
#  'sadiqabad',
#  'amapa',
#  'te anau',
#  'kosonsoy',
#  'naryan-mar',
#  'solovetskiy',
#  'lagoa',
#  'novotroitsk',
#  'moose factory',
#  'impfondo',
#  'mandla',
#  'altay',
#  'pacific grove',
#  'bayji',
#  'naze',
#  'sentyabrskiy',
#  'vila velha',
#  'shakawe',
#  'rawannawi',
#  'saint-leu',
#  'adrar',
#  'ornskoldsvik',
#  'opuwo',
#  'sao miguel do araguaia',
#  'roald',
#  'hamilton',
#  'poronaysk',
#  'khovu-aksy',
#  'shimoda',
#  'muscat',
#  'maliq',
#  'asau',
#  'agirish',
#  'puerto escondido',
#  'walvis bay',
#  'la tuque',
#  'kamiiso',
#  'mathbaria',
#  'benguela',
#  'sinjar',
#  'chumikan',
#  'sao geraldo do araguaia',
#  'vredefort',
#  'beringovskiy',
#  'corpus christi',
#  'garden city',
#  'naral',
#  'ingham',
#  'daru',
#  'maltahohe',
#  'silifke',
#  'dicabisagan',
#  'samur',
#  'northam',
#  'broken hill',
#  'yashkul',
#  'mantua',
#  'nizwa',
#  'itaituba',
#  'bilma',
#  'ugoofaaru',
#  'makat',
#  'kalabo',
#  'conway',
#  'marfino',
#  'kavaratti',
#  'kenai',
#  'gombe',
#  'abha',
#  'baghdad',
#  'tselinnoye',
#  'umzimvubu',
#  'gladstone',
#  'fergus falls',
#  'primorsk',
#  'chapais',
#  'poum',
#  'avera',
#  'nyurba',
#  'melfi',
#  'kon tum',
#  'samos',
#  'sola',
#  'hengyang',
#  'cidreira',
#  'concarneau',
#  'vitim',
#  'wonogiri',
#  'amazar',
#  'beira',
#  'ponta delgada',
#  'launceston',
#  'kaoma',
#  'kavieng',
#  'iberia',
#  'hibbing',
#  'pontiac',
#  'springfield',
#  'rio gallegos',
#  'atar',
#  'katangli',
#  'vestmannaeyjar',
#  'manadhoo',
#  'carikar',
#  'kedrovyy',
#  'sehithwa',
#  'leh',
#  'rio claro',
#  'revelstoke',
#  'khasan',
#  'sluknov',
#  'sibolga',
#  'alice springs',
#  'yenagoa',
#  'namibe',
#  'waddan',
#  'kjollefjord',
#  'mangrol',
#  'manggar',
#  'madridejos',
#  'pitea',
#  'itarema',
#  'mirnyy',
#  'san policarpo',
#  'marcona',
#  'salisbury',
#  'santa vitoria do palmar',
#  'labuan',
#  'arkhangelos',
#  'dalby',
#  'saint-joseph',
#  'suntar',
#  'jiayuguan',
#  'constitucion',
#  'yulara',
#  'kununurra',
#  'krasnyy kholm',
#  'gossaigaon',
#  'nemuro',
#  'iisalmi',
#  'yeppoon',
#  'calabozo',
#  'bodden town',
#  'luanda',
#  'gushikawa',
#  'nome',
#  'vila',
#  'marau',
#  'hirado',
#  'mhango',
#  'doka',
#  'manthani',
#  'salalah',
#  'khani',
#  'shugurovo',
#  'andenes',
#  'tecolutla',
#  'cagayan de tawi-tawi',
#  'varkkallai',
#  'ostersund',
#  'karratha',
#  'whyalla',
#  'kharabali',
#  'gorontalo',
#  'zyryanskoye',
#  'olafsvik',
#  'mwense',
#  'nelson bay',
#  'ayia galini',
#  'baiyin',
#  'tamboril',
#  'meyungs',
#  'nauta',
#  'hendijan',
#  'riyadh',
#  'thiruvananthapuram',
#  'lemesos',
#  'westport',
#  'pesnica pri mariboru',
#  'kayes',
#  'agua prieta',
#  'quepos',
#  'san patricio',
#  'penzance',
#  'berlevag',
#  'acapulco',
#  'magan',
#  'asayita',
#  'balykshi',
#  'san rafael',
#  'omboue',
#  'porto novo',
#  'marawi',
#  'batamshinskiy',
#  'along',
#  'sinkat',
#  'killybegs',
#  'porrentruy',
#  'imbituba',
#  'ikalamavony',
#  'esmeralda',
#  'warqla',
#  'volot',
#  'guarapari',
#  'dakoro',
#  'ust-kamchatsk',
#  'palamos',
#  'port-de-bouc',
#  'traiguen',
#  'fereydunshahr',
#  'haines junction',
#  'lagos',
#  'koroni',
#  'caxias',
#  'mackay',
#  'perambalur',
#  'palmer',
#  'usinsk',
#  'iralaya',
#  'fort frances',
#  'canhotinho',
#  'paulo afonso',
#  'ayorou',
#  'khash',
#  'zhezkazgan',
#  'cao bang',
#  'saraland',
#  'bernburg',
#  'mayor pablo lagerenza',
#  'cordoba',
#  'baraolt',
#  'kungurtug',
#  'tir pol',
#  'tura',
#  'truckee',
#  'toora-khem',
#  'antalaha',
#  'cacu',
#  'atasu',
#  'caldwell',
#  'esmeraldas',
#  'port said',
#  'abalak',
#  'port hardy',
#  'drumnadrochit',
#  'tarko-sale',
#  'grand haven',
#  'bardiyah',
#  'iracoubo',
#  'santa maria',
#  'araouane',
#  'thinadhoo',
#  'yaan',
#  'zyryanka',
#  'pervomayskoye',
#  'inirida',
#  'excelsior springs',
#  'manaia',
#  'skagastrond',
#  'oxford',
#  'oneonta',
#  'chitungwiza',
#  'awbari',
#  'ngukurr',
#  'bodmin',
#  'kalengwa',
#  'kehra',
#  'kiama',
#  'broome',
#  'qom',
#  'kahului',
#  'conselheiro lafaiete',
#  'lata',
#  'bahia de caraquez',
#  'dudinka',
#  'chimoio',
#  'bereznik',
#  'arkhangelskoye',
#  'biak',
#  'nalut',
#  'porosozero',
#  'timra',
#  'tazovskiy',
#  'verkhnevilyuysk',
#  'sao desiderio',
#  'at-bashi',
#  'ulaanbaatar',
#  'ajuchitlan',
#  'hihifo',
#  'tamandare',
#  'paris',
#  'durango',
#  'sai buri',
#  'boyolangu',
#  'tessalit',
#  'miri',
#  'coos bay',
#  'semnan',
#  'kutum',
#  'pimenteiras',
#  'bilibino',
#  'jablah',
#  'bacuit',
#  'solhan',
#  'dolinsk',
#  'ca mau',
#  'mount gambier',
#  'baherden',
#  'ippy',
#  'bayburt',
#  'bereda',
#  'morondava',
#  'svetlyy',
#  'lunenburg',
#  'komsomolskiy',
#  'kokopo',
#  'outlook',
#  'satitoa',
#  'morges',
#  'gzhatsk',
#  'pisco',
#  'maoming',
#  'qesarya',
#  'havoysund',
#  'port augusta',
#  'duz',
#  'acajutla',
#  'ust-maya',
#  'butterworth',
#  'lakki marwat',
#  'cherskiy',
#  'san juan',
#  'tiruvallur',
#  'rabat',
#  'taquara',
#  'dickinson',
#  'henties bay',
#  'tual',
#  'bandundu',
#  'kalmunai',
#  'lodja',
#  'santa marinella',
#  'port hawkesbury',
#  'cam ranh',
#  'monrovia',
#  'yarmouth',
#  'midland',
#  'porto santo',
#  'ipixuna',
#  'bure',
#  'romitan',
#  'aligudarz',
#  'mount hagen',
#  'atbasar',
#  'funadhoo',
#  'notre-dame-du-lac',
#  'muravlenko',
#  'suphan buri',
#  'rochegda',
#  'novokuznetsk',
#  'ayr',
#  'sangar',
#  'brigantine',
#  'bobo dioulasso',
#  'portoferraio',
#  'ngunguru',
#  'prince rupert',
#  'rio grande',
#  'zhigalovo',
#  'kaeo',
#  'vostok',
#  'winslow',
#  'ternate',
#  'finote selam']

# %% [markdown]
# # Perform an API Call with OpenWeatherMap

# %%
# create empty list to hold city weather data
city_data = []

# print beginning of logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# create counters to see progress
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %% [markdown]
# # Retrieve lat/lng, max temp, %humidity, %cloudiness, wind speed, weather description

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weatherDescription = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_weatherDescription,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("error")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | taolanaro
# error
# Processing Record 2 of Set 1 | kargasok
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | iqaluit
# Processing Record 5 of Set 1 | barentsburg
# error
# Processing Record 6 of Set 1 | ahipara
# Processing Record 7 of Set 1 | hobyo
# Processing Record 8 of Set 1 | saint-philippe
# Processing Record 9 of Set 1 | isangel
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | bubaque
# Processing Record 13 of Set 1 | kawhia
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | xining
# Processing Record 16 of Set 1 | villa bruzual
# Processing Record 17 of Set 1 | half moon bay
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | galle
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | srednekolymsk
# Processing Record 23 of Set 1 | meulaboh
# Processing Record 24 of Set 1 | victoria
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | klaksvik
# Processing Record 27 of Set 1 | port blair
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | mildura
# Processing Record 30 of Set 1 | kerki
# error
# Processing Record 31 of Set 1 | barrow
# Processing Record 32 of Set 1 | new norfolk
# Processing Record 33 of Set 1 | kapaa
# Processing Record 34 of Set 1 | evensk
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | mys shmidta
# error
# Processing Record 37 of Set 1 | maraa
# Processing Record 38 of Set 1 | tuktoyaktuk
# Processing Record 39 of Set 1 | aleksandrovka
# Processing Record 40 of Set 1 | ust-kuyga
# Processing Record 41 of Set 1 | saskylakh
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | jalu
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | luba
# Processing Record 48 of Set 1 | ponta do sol
# Processing Record 49 of Set 1 | grindavik
# Processing Record 50 of Set 1 | kirensk
# Processing Record 1 of Set 2 | nizhneyansk
# error
# Processing Record 2 of Set 2 | marsh harbour
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | alofi
# Processing Record 5 of Set 2 | yumen
# Processing Record 6 of Set 2 | abu dhabi
# Processing Record 7 of Set 2 | chulman
# Processing Record 8 of Set 2 | tabuk
# Processing Record 9 of Set 2 | lavrentiya
# Processing Record 10 of Set 2 | aklavik
# Processing Record 11 of Set 2 | illoqqortoormiut
# error
# Processing Record 12 of Set 2 | esperance
# Processing Record 13 of Set 2 | zhigansk
# Processing Record 14 of Set 2 | faya
# Processing Record 15 of Set 2 | kassala
# Processing Record 16 of Set 2 | salinas
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | temaraia
# error
# Processing Record 19 of Set 2 | ixtapa
# Processing Record 20 of Set 2 | plettenberg bay
# Processing Record 21 of Set 2 | chokurdakh
# Processing Record 22 of Set 2 | codrington
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | kuytun
# Processing Record 25 of Set 2 | innisfail
# Processing Record 26 of Set 2 | honiara
# Processing Record 27 of Set 2 | mount isa
# Processing Record 28 of Set 2 | port elizabeth
# Processing Record 29 of Set 2 | bredasdorp
# Processing Record 30 of Set 2 | yelizovo
# Processing Record 31 of Set 2 | malinovoye ozero
# Processing Record 32 of Set 2 | avarua
# Processing Record 33 of Set 2 | ilkal
# Processing Record 34 of Set 2 | nikolskoye
# Processing Record 35 of Set 2 | georgetown
# Processing Record 36 of Set 2 | bluff
# Processing Record 37 of Set 2 | lebu
# Processing Record 38 of Set 2 | casper
# Processing Record 39 of Set 2 | salym
# Processing Record 40 of Set 2 | pangnirtung
# Processing Record 41 of Set 2 | cervo
# Processing Record 42 of Set 2 | seymchan
# Processing Record 43 of Set 2 | pevek
# Processing Record 44 of Set 2 | ha giang
# Processing Record 45 of Set 2 | karpathos
# Processing Record 46 of Set 2 | baculin
# Processing Record 47 of Set 2 | albany
# Processing Record 48 of Set 2 | hithadhoo
# Processing Record 49 of Set 2 | zabinka
# error
# Processing Record 50 of Set 2 | butaritari
# Processing Record 1 of Set 3 | yellowknife
# Processing Record 2 of Set 3 | poros
# Processing Record 3 of Set 3 | comodoro rivadavia
# Processing Record 4 of Set 3 | marsa matruh
# Processing Record 5 of Set 3 | karasjok
# Processing Record 6 of Set 3 | touros
# Processing Record 7 of Set 3 | nouadhibou
# Processing Record 8 of Set 3 | guerrero negro
# Processing Record 9 of Set 3 | portland
# Processing Record 10 of Set 3 | mar del plata
# Processing Record 11 of Set 3 | mocambique
# error
# Processing Record 12 of Set 3 | finschhafen
# Processing Record 13 of Set 3 | sao filipe
# Processing Record 14 of Set 3 | santiago
# Processing Record 15 of Set 3 | khatanga
# Processing Record 16 of Set 3 | rungata
# error
# Processing Record 17 of Set 3 | hofn
# Processing Record 18 of Set 3 | pochutla
# Processing Record 19 of Set 3 | linchuan
# error
# Processing Record 20 of Set 3 | bengkulu
# Processing Record 21 of Set 3 | fortuna
# Processing Record 22 of Set 3 | saint-augustin
# Processing Record 23 of Set 3 | qandala
# Processing Record 24 of Set 3 | alyangula
# Processing Record 25 of Set 3 | kaliua
# Processing Record 26 of Set 3 | thompson
# Processing Record 27 of Set 3 | hobart
# Processing Record 28 of Set 3 | saldanha
# Processing Record 29 of Set 3 | saint-francois
# Processing Record 30 of Set 3 | manitouwadge
# Processing Record 31 of Set 3 | hambantota
# Processing Record 32 of Set 3 | hovd
# Processing Record 33 of Set 3 | hilo
# Processing Record 34 of Set 3 | nichinan
# Processing Record 35 of Set 3 | acoua
# Processing Record 36 of Set 3 | port moresby
# Processing Record 37 of Set 3 | saint george
# Processing Record 38 of Set 3 | megion
# Processing Record 39 of Set 3 | cockburn town
# Processing Record 40 of Set 3 | lasa
# Processing Record 41 of Set 3 | sisimiut
# Processing Record 42 of Set 3 | vieques
# Processing Record 43 of Set 3 | clyde river
# Processing Record 44 of Set 3 | kodiak
# Processing Record 45 of Set 3 | fairbanks
# Processing Record 46 of Set 3 | blenheim
# Processing Record 47 of Set 3 | waingapu
# Processing Record 48 of Set 3 | rocha
# Processing Record 49 of Set 3 | pietarsaari
# Processing Record 50 of Set 3 | talnakh
# Processing Record 1 of Set 4 | boa vista
# Processing Record 2 of Set 4 | vryburg
# Processing Record 3 of Set 4 | kruisfontein
# Processing Record 4 of Set 4 | harbour breton
# Processing Record 5 of Set 4 | kelc
# Processing Record 6 of Set 4 | arandis
# Processing Record 7 of Set 4 | lorengau
# Processing Record 8 of Set 4 | tsihombe
# error
# Processing Record 9 of Set 4 | mamallapuram
# Processing Record 10 of Set 4 | upernavik
# Processing Record 11 of Set 4 | axim
# Processing Record 12 of Set 4 | romny
# Processing Record 13 of Set 4 | taseyevo
# Processing Record 14 of Set 4 | dingle
# Processing Record 15 of Set 4 | los llanos de aridane
# Processing Record 16 of Set 4 | port macquarie
# Processing Record 17 of Set 4 | ribeira grande
# Processing Record 18 of Set 4 | kizukuri
# Processing Record 19 of Set 4 | eirunepe
# Processing Record 20 of Set 4 | tenkodogo
# Processing Record 21 of Set 4 | kawalu
# Processing Record 22 of Set 4 | amderma
# error
# Processing Record 23 of Set 4 | cabo san lucas
# Processing Record 24 of Set 4 | yamada
# Processing Record 25 of Set 4 | suez
# Processing Record 26 of Set 4 | leningradskiy
# Processing Record 27 of Set 4 | gannan
# Processing Record 28 of Set 4 | turukhansk
# Processing Record 29 of Set 4 | craig
# Processing Record 30 of Set 4 | yar-sale
# Processing Record 31 of Set 4 | lolua
# error
# Processing Record 32 of Set 4 | kudahuvadhoo
# Processing Record 33 of Set 4 | gat
# Processing Record 34 of Set 4 | zonguldak
# Processing Record 35 of Set 4 | cheuskiny
# error
# Processing Record 36 of Set 4 | chernyshevskiy
# Processing Record 37 of Set 4 | soyo
# Processing Record 38 of Set 4 | flinders
# Processing Record 39 of Set 4 | yuncheng
# Processing Record 40 of Set 4 | pilot butte
# Processing Record 41 of Set 4 | illela
# Processing Record 42 of Set 4 | havelock
# Processing Record 43 of Set 4 | requena
# Processing Record 44 of Set 4 | virovitica
# Processing Record 45 of Set 4 | birecik
# Processing Record 46 of Set 4 | setermoen
# Processing Record 47 of Set 4 | mayo
# Processing Record 48 of Set 4 | sao joao da barra
# Processing Record 49 of Set 4 | kaitangata
# Processing Record 50 of Set 4 | kloulklubed
# Processing Record 1 of Set 5 | mehamn
# Processing Record 2 of Set 5 | grand river south east
# error
# Processing Record 3 of Set 5 | moussoro
# Processing Record 4 of Set 5 | port-gentil
# Processing Record 5 of Set 5 | tumannyy
# error
# Processing Record 6 of Set 5 | aktau
# Processing Record 7 of Set 5 | khoy
# Processing Record 8 of Set 5 | tuggurt
# error
# Processing Record 9 of Set 5 | ust-omchug
# Processing Record 10 of Set 5 | college
# Processing Record 11 of Set 5 | bandarbeyla
# Processing Record 12 of Set 5 | imeni zhelyabova
# Processing Record 13 of Set 5 | cueramaro
# Processing Record 14 of Set 5 | chuy
# Processing Record 15 of Set 5 | ossora
# Processing Record 16 of Set 5 | aktas
# Processing Record 17 of Set 5 | longyearbyen
# Processing Record 18 of Set 5 | praia da vitoria
# Processing Record 19 of Set 5 | gurupa
# Processing Record 20 of Set 5 | yatou
# Processing Record 21 of Set 5 | port lincoln
# Processing Record 22 of Set 5 | laguna
# Processing Record 23 of Set 5 | luderitz
# Processing Record 24 of Set 5 | provideniya
# Processing Record 25 of Set 5 | banda aceh
# Processing Record 26 of Set 5 | teya
# Processing Record 27 of Set 5 | stromness
# Processing Record 28 of Set 5 | geraldton
# Processing Record 29 of Set 5 | katsuura
# Processing Record 30 of Set 5 | bambous virieux
# Processing Record 31 of Set 5 | torbay
# Processing Record 32 of Set 5 | svetlogorsk
# Processing Record 33 of Set 5 | huarmey
# Processing Record 34 of Set 5 | samusu
# error
# Processing Record 35 of Set 5 | mahebourg
# Processing Record 36 of Set 5 | vardo
# Processing Record 37 of Set 5 | faxinal
# Processing Record 38 of Set 5 | tasiilaq
# Processing Record 39 of Set 5 | segezha
# Processing Record 40 of Set 5 | pizarro
# Processing Record 41 of Set 5 | ferrandina
# Processing Record 42 of Set 5 | kodinsk
# Processing Record 43 of Set 5 | dwarka
# Processing Record 44 of Set 5 | anadyr
# Processing Record 45 of Set 5 | svetlaya
# Processing Record 46 of Set 5 | rawson
# Processing Record 47 of Set 5 | coquimbo
# Processing Record 48 of Set 5 | quatre cocos
# Processing Record 49 of Set 5 | vaitupu
# error
# Processing Record 50 of Set 5 | grand-santi
# Processing Record 1 of Set 6 | tiksi
# Processing Record 2 of Set 6 | khandyga
# Processing Record 3 of Set 6 | airai
# Processing Record 4 of Set 6 | abnub
# Processing Record 5 of Set 6 | south river
# Processing Record 6 of Set 6 | goderich
# Processing Record 7 of Set 6 | saint anthony
# Processing Record 8 of Set 6 | ilulissat
# Processing Record 9 of Set 6 | springbok
# Processing Record 10 of Set 6 | natitingou
# Processing Record 11 of Set 6 | matara
# Processing Record 12 of Set 6 | sitka
# Processing Record 13 of Set 6 | shenjiamen
# Processing Record 14 of Set 6 | taft
# Processing Record 15 of Set 6 | caravelas
# Processing Record 16 of Set 6 | micomeseng
# Processing Record 17 of Set 6 | belushya guba
# error
# Processing Record 18 of Set 6 | okhotsk
# Processing Record 19 of Set 6 | tomatlan
# Processing Record 20 of Set 6 | mitsamiouli
# Processing Record 21 of Set 6 | ust-ilimsk
# Processing Record 22 of Set 6 | la ronge
# Processing Record 23 of Set 6 | khorixas
# Processing Record 24 of Set 6 | muncar
# Processing Record 25 of Set 6 | jacmel
# Processing Record 26 of Set 6 | severo-kurilsk
# Processing Record 27 of Set 6 | pucallpa
# Processing Record 28 of Set 6 | basco
# Processing Record 29 of Set 6 | nekrasovka
# Processing Record 30 of Set 6 | norman wells
# Processing Record 31 of Set 6 | attawapiskat
# error
# Processing Record 32 of Set 6 | safaga
# Processing Record 33 of Set 6 | muriwai beach
# Processing Record 34 of Set 6 | auki
# Processing Record 35 of Set 6 | hirara
# Processing Record 36 of Set 6 | sarai alamgir
# Processing Record 37 of Set 6 | mascota
# Processing Record 38 of Set 6 | wareham
# Processing Record 39 of Set 6 | kemijarvi
# Processing Record 40 of Set 6 | mont-dore
# Processing Record 41 of Set 6 | muyezerskiy
# Processing Record 42 of Set 6 | batagay-alyta
# Processing Record 43 of Set 6 | tuatapere
# Processing Record 44 of Set 6 | sao felix do xingu
# Processing Record 45 of Set 6 | haimen
# Processing Record 46 of Set 6 | dalbandin
# Processing Record 47 of Set 6 | padang
# Processing Record 48 of Set 6 | carnarvon
# Processing Record 49 of Set 6 | nanortalik
# Processing Record 50 of Set 6 | copiapo
# Processing Record 1 of Set 7 | leshukonskoye
# Processing Record 2 of Set 7 | makung
# error
# Processing Record 3 of Set 7 | himora
# error
# Processing Record 4 of Set 7 | karaul
# error
# Processing Record 5 of Set 7 | sorland
# Processing Record 6 of Set 7 | bosaso
# Processing Record 7 of Set 7 | takoradi
# Processing Record 8 of Set 7 | mareeba
# Processing Record 9 of Set 7 | bambanglipuro
# Processing Record 10 of Set 7 | kalawit
# Processing Record 11 of Set 7 | maputo
# Processing Record 12 of Set 7 | san quintin
# Processing Record 13 of Set 7 | hasaki
# Processing Record 14 of Set 7 | aquiraz
# Processing Record 15 of Set 7 | faanui
# Processing Record 16 of Set 7 | candawaga
# error
# Processing Record 17 of Set 7 | careiro da varzea
# Processing Record 18 of Set 7 | maceio
# Processing Record 19 of Set 7 | arica
# Processing Record 20 of Set 7 | vila franca do campo
# Processing Record 21 of Set 7 | noumea
# Processing Record 22 of Set 7 | margate
# Processing Record 23 of Set 7 | seoul
# Processing Record 24 of Set 7 | sorvag
# error
# Processing Record 25 of Set 7 | pimenta bueno
# Processing Record 26 of Set 7 | chengde
# Processing Record 27 of Set 7 | boffa
# Processing Record 28 of Set 7 | sanchazi
# Processing Record 29 of Set 7 | sovetskiy
# Processing Record 30 of Set 7 | kang
# Processing Record 31 of Set 7 | arlit
# Processing Record 32 of Set 7 | samarai
# Processing Record 33 of Set 7 | san cristobal
# Processing Record 34 of Set 7 | lamesa
# Processing Record 35 of Set 7 | vao
# Processing Record 36 of Set 7 | tautira
# Processing Record 37 of Set 7 | taoudenni
# Processing Record 38 of Set 7 | natal
# Processing Record 39 of Set 7 | souillac
# Processing Record 40 of Set 7 | fare
# Processing Record 41 of Set 7 | lompoc
# Processing Record 42 of Set 7 | ancud
# Processing Record 43 of Set 7 | msowero
# Processing Record 44 of Set 7 | ndende
# Processing Record 45 of Set 7 | karoi
# Processing Record 46 of Set 7 | kochki
# Processing Record 47 of Set 7 | galveston
# Processing Record 48 of Set 7 | tilichiki
# Processing Record 49 of Set 7 | sogdiondon
# error
# Processing Record 50 of Set 7 | puri
# Processing Record 1 of Set 8 | santa cruz
# Processing Record 2 of Set 8 | belyy yar
# Processing Record 3 of Set 8 | hadishahr
# Processing Record 4 of Set 8 | hami
# Processing Record 5 of Set 8 | pimentel
# Processing Record 6 of Set 8 | mogocha
# Processing Record 7 of Set 8 | puerto colombia
# Processing Record 8 of Set 8 | nabire
# Processing Record 9 of Set 8 | castro
# Processing Record 10 of Set 8 | inhambane
# Processing Record 11 of Set 8 | sarangani
# Processing Record 12 of Set 8 | maragogi
# Processing Record 13 of Set 8 | lokosovo
# Processing Record 14 of Set 8 | batagay
# Processing Record 15 of Set 8 | wamba
# Processing Record 16 of Set 8 | sadiqabad
# Processing Record 17 of Set 8 | amapa
# Processing Record 18 of Set 8 | te anau
# Processing Record 19 of Set 8 | kosonsoy
# Processing Record 20 of Set 8 | naryan-mar
# Processing Record 21 of Set 8 | solovetskiy
# error
# Processing Record 22 of Set 8 | lagoa
# Processing Record 23 of Set 8 | novotroitsk
# Processing Record 24 of Set 8 | moose factory
# Processing Record 25 of Set 8 | impfondo
# Processing Record 26 of Set 8 | mandla
# Processing Record 27 of Set 8 | altay
# Processing Record 28 of Set 8 | pacific grove
# Processing Record 29 of Set 8 | bayji
# Processing Record 30 of Set 8 | naze
# Processing Record 31 of Set 8 | sentyabrskiy
# error
# Processing Record 32 of Set 8 | vila velha
# Processing Record 33 of Set 8 | shakawe
# Processing Record 34 of Set 8 | rawannawi
# error
# Processing Record 35 of Set 8 | saint-leu
# Processing Record 36 of Set 8 | adrar
# Processing Record 37 of Set 8 | ornskoldsvik
# Processing Record 38 of Set 8 | opuwo
# Processing Record 39 of Set 8 | sao miguel do araguaia
# Processing Record 40 of Set 8 | roald
# Processing Record 41 of Set 8 | hamilton
# Processing Record 42 of Set 8 | poronaysk
# Processing Record 43 of Set 8 | khovu-aksy
# Processing Record 44 of Set 8 | shimoda
# Processing Record 45 of Set 8 | muscat
# Processing Record 46 of Set 8 | maliq
# Processing Record 47 of Set 8 | asau
# Processing Record 48 of Set 8 | agirish
# Processing Record 49 of Set 8 | puerto escondido
# Processing Record 50 of Set 8 | walvis bay
# Processing Record 1 of Set 9 | la tuque
# Processing Record 2 of Set 9 | kamiiso
# Processing Record 3 of Set 9 | mathbaria
# Processing Record 4 of Set 9 | benguela
# Processing Record 5 of Set 9 | sinjar
# Processing Record 6 of Set 9 | chumikan
# Processing Record 7 of Set 9 | sao geraldo do araguaia
# Processing Record 8 of Set 9 | vredefort
# Processing Record 9 of Set 9 | beringovskiy
# Processing Record 10 of Set 9 | corpus christi
# Processing Record 11 of Set 9 | garden city
# Processing Record 12 of Set 9 | naral
# error
# Processing Record 13 of Set 9 | ingham
# Processing Record 14 of Set 9 | daru
# Processing Record 15 of Set 9 | maltahohe
# Processing Record 16 of Set 9 | silifke
# Processing Record 17 of Set 9 | dicabisagan
# Processing Record 18 of Set 9 | samur
# Processing Record 19 of Set 9 | northam
# Processing Record 20 of Set 9 | broken hill
# Processing Record 21 of Set 9 | yashkul
# Processing Record 22 of Set 9 | mantua
# Processing Record 23 of Set 9 | nizwa
# Processing Record 24 of Set 9 | itaituba
# Processing Record 25 of Set 9 | bilma
# Processing Record 26 of Set 9 | ugoofaaru
# Processing Record 27 of Set 9 | makat
# Processing Record 28 of Set 9 | kalabo
# Processing Record 29 of Set 9 | conway
# Processing Record 30 of Set 9 | marfino
# Processing Record 31 of Set 9 | kavaratti
# Processing Record 32 of Set 9 | kenai
# Processing Record 33 of Set 9 | gombe
# Processing Record 34 of Set 9 | abha
# Processing Record 35 of Set 9 | baghdad
# Processing Record 36 of Set 9 | tselinnoye
# Processing Record 37 of Set 9 | umzimvubu
# error
# Processing Record 38 of Set 9 | gladstone
# Processing Record 39 of Set 9 | fergus falls
# Processing Record 40 of Set 9 | primorsk
# Processing Record 41 of Set 9 | chapais
# Processing Record 42 of Set 9 | poum
# Processing Record 43 of Set 9 | avera
# Processing Record 44 of Set 9 | nyurba
# Processing Record 45 of Set 9 | melfi
# Processing Record 46 of Set 9 | kon tum
# Processing Record 47 of Set 9 | samos
# Processing Record 48 of Set 9 | sola
# Processing Record 49 of Set 9 | hengyang
# Processing Record 50 of Set 9 | cidreira
# Processing Record 1 of Set 10 | concarneau
# Processing Record 2 of Set 10 | vitim
# Processing Record 3 of Set 10 | wonogiri
# Processing Record 4 of Set 10 | amazar
# Processing Record 5 of Set 10 | beira
# Processing Record 6 of Set 10 | ponta delgada
# Processing Record 7 of Set 10 | launceston
# Processing Record 8 of Set 10 | kaoma
# Processing Record 9 of Set 10 | kavieng
# Processing Record 10 of Set 10 | iberia
# Processing Record 11 of Set 10 | hibbing
# Processing Record 12 of Set 10 | pontiac
# Processing Record 13 of Set 10 | springfield
# Processing Record 14 of Set 10 | rio gallegos
# Processing Record 15 of Set 10 | atar
# Processing Record 16 of Set 10 | katangli
# Processing Record 17 of Set 10 | vestmannaeyjar
# Processing Record 18 of Set 10 | manadhoo
# Processing Record 19 of Set 10 | carikar
# error
# Processing Record 20 of Set 10 | kedrovyy
# Processing Record 21 of Set 10 | sehithwa
# Processing Record 22 of Set 10 | leh
# Processing Record 23 of Set 10 | rio claro
# Processing Record 24 of Set 10 | revelstoke
# Processing Record 25 of Set 10 | khasan
# Processing Record 26 of Set 10 | sluknov
# Processing Record 27 of Set 10 | sibolga
# Processing Record 28 of Set 10 | alice springs
# Processing Record 29 of Set 10 | yenagoa
# Processing Record 30 of Set 10 | namibe
# Processing Record 31 of Set 10 | waddan
# Processing Record 32 of Set 10 | kjollefjord
# Processing Record 33 of Set 10 | mangrol
# Processing Record 34 of Set 10 | manggar
# Processing Record 35 of Set 10 | madridejos
# Processing Record 36 of Set 10 | pitea
# Processing Record 37 of Set 10 | itarema
# Processing Record 38 of Set 10 | mirnyy
# Processing Record 39 of Set 10 | san policarpo
# Processing Record 40 of Set 10 | marcona
# error
# Processing Record 41 of Set 10 | salisbury
# Processing Record 42 of Set 10 | santa vitoria do palmar
# Processing Record 43 of Set 10 | labuan
# Processing Record 44 of Set 10 | arkhangelos
# error
# Processing Record 45 of Set 10 | dalby
# Processing Record 46 of Set 10 | saint-joseph
# Processing Record 47 of Set 10 | suntar
# Processing Record 48 of Set 10 | jiayuguan
# Processing Record 49 of Set 10 | constitucion
# Processing Record 50 of Set 10 | yulara
# Processing Record 1 of Set 11 | kununurra
# Processing Record 2 of Set 11 | krasnyy kholm
# Processing Record 3 of Set 11 | gossaigaon
# Processing Record 4 of Set 11 | nemuro
# Processing Record 5 of Set 11 | iisalmi
# Processing Record 6 of Set 11 | yeppoon
# Processing Record 7 of Set 11 | calabozo
# Processing Record 8 of Set 11 | bodden town
# Processing Record 9 of Set 11 | luanda
# Processing Record 10 of Set 11 | gushikawa
# Processing Record 11 of Set 11 | nome
# Processing Record 12 of Set 11 | vila
# Processing Record 13 of Set 11 | marau
# Processing Record 14 of Set 11 | hirado
# Processing Record 15 of Set 11 | mhango
# Processing Record 16 of Set 11 | doka
# Processing Record 17 of Set 11 | manthani
# Processing Record 18 of Set 11 | salalah
# Processing Record 19 of Set 11 | khani
# Processing Record 20 of Set 11 | shugurovo
# Processing Record 21 of Set 11 | andenes
# Processing Record 22 of Set 11 | tecolutla
# Processing Record 23 of Set 11 | cagayan de tawi-tawi
# error
# Processing Record 24 of Set 11 | varkkallai
# Processing Record 25 of Set 11 | ostersund
# Processing Record 26 of Set 11 | karratha
# Processing Record 27 of Set 11 | whyalla
# Processing Record 28 of Set 11 | kharabali
# Processing Record 29 of Set 11 | gorontalo
# Processing Record 30 of Set 11 | zyryanskoye
# Processing Record 31 of Set 11 | olafsvik
# Processing Record 32 of Set 11 | mwense
# Processing Record 33 of Set 11 | nelson bay
# Processing Record 34 of Set 11 | ayia galini
# Processing Record 35 of Set 11 | baiyin
# Processing Record 36 of Set 11 | tamboril
# Processing Record 37 of Set 11 | meyungs
# error
# Processing Record 38 of Set 11 | nauta
# Processing Record 39 of Set 11 | hendijan
# error
# Processing Record 40 of Set 11 | riyadh
# Processing Record 41 of Set 11 | thiruvananthapuram
# Processing Record 42 of Set 11 | lemesos
# error
# Processing Record 43 of Set 11 | westport
# Processing Record 44 of Set 11 | pesnica pri mariboru
# Processing Record 45 of Set 11 | kayes
# Processing Record 46 of Set 11 | agua prieta
# Processing Record 47 of Set 11 | quepos
# Processing Record 48 of Set 11 | san patricio
# Processing Record 49 of Set 11 | penzance
# Processing Record 50 of Set 11 | berlevag
# Processing Record 1 of Set 12 | acapulco
# Processing Record 2 of Set 12 | magan
# Processing Record 3 of Set 12 | asayita
# error
# Processing Record 4 of Set 12 | balykshi
# Processing Record 5 of Set 12 | san rafael
# Processing Record 6 of Set 12 | omboue
# Processing Record 7 of Set 12 | porto novo
# Processing Record 8 of Set 12 | marawi
# Processing Record 9 of Set 12 | batamshinskiy
# Processing Record 10 of Set 12 | along
# Processing Record 11 of Set 12 | sinkat
# error
# Processing Record 12 of Set 12 | killybegs
# Processing Record 13 of Set 12 | porrentruy
# Processing Record 14 of Set 12 | imbituba
# Processing Record 15 of Set 12 | ikalamavony
# Processing Record 16 of Set 12 | esmeralda
# Processing Record 17 of Set 12 | warqla
# error
# Processing Record 18 of Set 12 | volot
# Processing Record 19 of Set 12 | guarapari
# Processing Record 20 of Set 12 | dakoro
# Processing Record 21 of Set 12 | ust-kamchatsk
# error
# Processing Record 22 of Set 12 | palamos
# Processing Record 23 of Set 12 | port-de-bouc
# Processing Record 24 of Set 12 | traiguen
# Processing Record 25 of Set 12 | fereydunshahr
# Processing Record 26 of Set 12 | haines junction
# Processing Record 27 of Set 12 | lagos
# Processing Record 28 of Set 12 | koroni
# Processing Record 29 of Set 12 | caxias
# Processing Record 30 of Set 12 | mackay
# Processing Record 31 of Set 12 | perambalur
# Processing Record 32 of Set 12 | palmer
# Processing Record 33 of Set 12 | usinsk
# Processing Record 34 of Set 12 | iralaya
# Processing Record 35 of Set 12 | fort frances
# Processing Record 36 of Set 12 | canhotinho
# Processing Record 37 of Set 12 | paulo afonso
# Processing Record 38 of Set 12 | ayorou
# Processing Record 39 of Set 12 | khash
# Processing Record 40 of Set 12 | zhezkazgan
# Processing Record 41 of Set 12 | cao bang
# Processing Record 42 of Set 12 | saraland
# Processing Record 43 of Set 12 | bernburg
# Processing Record 44 of Set 12 | mayor pablo lagerenza
# Processing Record 45 of Set 12 | cordoba
# Processing Record 46 of Set 12 | baraolt
# Processing Record 47 of Set 12 | kungurtug
# Processing Record 48 of Set 12 | tir pol
# error
# Processing Record 49 of Set 12 | tura
# Processing Record 50 of Set 12 | truckee
# Processing Record 1 of Set 13 | toora-khem
# Processing Record 2 of Set 13 | antalaha
# Processing Record 3 of Set 13 | cacu
# Processing Record 4 of Set 13 | atasu
# Processing Record 5 of Set 13 | caldwell
# Processing Record 6 of Set 13 | esmeraldas
# Processing Record 7 of Set 13 | port said
# Processing Record 8 of Set 13 | abalak
# Processing Record 9 of Set 13 | port hardy
# Processing Record 10 of Set 13 | drumnadrochit
# Processing Record 11 of Set 13 | tarko-sale
# Processing Record 12 of Set 13 | grand haven
# Processing Record 13 of Set 13 | bardiyah
# Processing Record 14 of Set 13 | iracoubo
# Processing Record 15 of Set 13 | santa maria
# Processing Record 16 of Set 13 | araouane
# Processing Record 17 of Set 13 | thinadhoo
# Processing Record 18 of Set 13 | yaan
# Processing Record 19 of Set 13 | zyryanka
# Processing Record 20 of Set 13 | pervomayskoye
# Processing Record 21 of Set 13 | inirida
# Processing Record 22 of Set 13 | excelsior springs
# Processing Record 23 of Set 13 | manaia
# Processing Record 24 of Set 13 | skagastrond
# error
# Processing Record 25 of Set 13 | oxford
# Processing Record 26 of Set 13 | oneonta
# Processing Record 27 of Set 13 | chitungwiza
# Processing Record 28 of Set 13 | awbari
# Processing Record 29 of Set 13 | ngukurr
# error
# Processing Record 30 of Set 13 | bodmin
# Processing Record 31 of Set 13 | kalengwa
# Processing Record 32 of Set 13 | kehra
# Processing Record 33 of Set 13 | kiama
# Processing Record 34 of Set 13 | broome
# Processing Record 35 of Set 13 | qom
# Processing Record 36 of Set 13 | kahului
# Processing Record 37 of Set 13 | conselheiro lafaiete
# Processing Record 38 of Set 13 | lata
# Processing Record 39 of Set 13 | bahia de caraquez
# Processing Record 40 of Set 13 | dudinka
# Processing Record 41 of Set 13 | chimoio
# Processing Record 42 of Set 13 | bereznik
# Processing Record 43 of Set 13 | arkhangelskoye
# Processing Record 44 of Set 13 | biak
# Processing Record 45 of Set 13 | nalut
# Processing Record 46 of Set 13 | porosozero
# Processing Record 47 of Set 13 | timra
# Processing Record 48 of Set 13 | tazovskiy
# Processing Record 49 of Set 13 | verkhnevilyuysk
# Processing Record 50 of Set 13 | sao desiderio
# Processing Record 1 of Set 14 | at-bashi
# Processing Record 2 of Set 14 | ulaanbaatar
# Processing Record 3 of Set 14 | ajuchitlan
# Processing Record 4 of Set 14 | hihifo
# error
# Processing Record 5 of Set 14 | tamandare
# Processing Record 6 of Set 14 | paris
# Processing Record 7 of Set 14 | durango
# Processing Record 8 of Set 14 | sai buri
# Processing Record 9 of Set 14 | boyolangu
# Processing Record 10 of Set 14 | tessalit
# Processing Record 11 of Set 14 | miri
# Processing Record 12 of Set 14 | coos bay
# Processing Record 13 of Set 14 | semnan
# Processing Record 14 of Set 14 | kutum
# Processing Record 15 of Set 14 | pimenteiras
# Processing Record 16 of Set 14 | bilibino
# Processing Record 17 of Set 14 | jablah
# Processing Record 18 of Set 14 | bacuit
# error
# Processing Record 19 of Set 14 | solhan
# Processing Record 20 of Set 14 | dolinsk
# Processing Record 21 of Set 14 | ca mau
# Processing Record 22 of Set 14 | mount gambier
# Processing Record 23 of Set 14 | baherden
# Processing Record 24 of Set 14 | ippy
# Processing Record 25 of Set 14 | bayburt
# Processing Record 26 of Set 14 | bereda
# Processing Record 27 of Set 14 | morondava
# Processing Record 28 of Set 14 | svetlyy
# Processing Record 29 of Set 14 | lunenburg
# Processing Record 30 of Set 14 | komsomolskiy
# Processing Record 31 of Set 14 | kokopo
# Processing Record 32 of Set 14 | outlook
# Processing Record 33 of Set 14 | satitoa
# error
# Processing Record 34 of Set 14 | morges
# Processing Record 35 of Set 14 | gzhatsk
# error
# Processing Record 36 of Set 14 | pisco
# Processing Record 37 of Set 14 | maoming
# Processing Record 38 of Set 14 | qesarya
# Processing Record 39 of Set 14 | havoysund
# Processing Record 40 of Set 14 | port augusta
# Processing Record 41 of Set 14 | duz
# error
# Processing Record 42 of Set 14 | acajutla
# Processing Record 43 of Set 14 | ust-maya
# Processing Record 44 of Set 14 | butterworth
# Processing Record 45 of Set 14 | lakki marwat
# Processing Record 46 of Set 14 | cherskiy
# Processing Record 47 of Set 14 | san juan
# Processing Record 48 of Set 14 | tiruvallur
# Processing Record 49 of Set 14 | rabat
# Processing Record 50 of Set 14 | taquara
# Processing Record 1 of Set 15 | dickinson
# Processing Record 2 of Set 15 | henties bay
# Processing Record 3 of Set 15 | tual
# Processing Record 4 of Set 15 | bandundu
# Processing Record 5 of Set 15 | kalmunai
# Processing Record 6 of Set 15 | lodja
# Processing Record 7 of Set 15 | santa marinella
# Processing Record 8 of Set 15 | port hawkesbury
# Processing Record 9 of Set 15 | cam ranh
# Processing Record 10 of Set 15 | monrovia
# Processing Record 11 of Set 15 | yarmouth
# Processing Record 12 of Set 15 | midland
# Processing Record 13 of Set 15 | porto santo
# Processing Record 14 of Set 15 | ipixuna
# Processing Record 15 of Set 15 | bure
# Processing Record 16 of Set 15 | romitan
# Processing Record 17 of Set 15 | aligudarz
# Processing Record 18 of Set 15 | mount hagen
# Processing Record 19 of Set 15 | atbasar
# Processing Record 20 of Set 15 | funadhoo
# Processing Record 21 of Set 15 | notre-dame-du-lac
# Processing Record 22 of Set 15 | muravlenko
# Processing Record 23 of Set 15 | suphan buri
# Processing Record 24 of Set 15 | rochegda
# Processing Record 25 of Set 15 | novokuznetsk
# Processing Record 26 of Set 15 | ayr
# Processing Record 27 of Set 15 | sangar
# Processing Record 28 of Set 15 | brigantine
# Processing Record 29 of Set 15 | bobo dioulasso
# Processing Record 30 of Set 15 | portoferraio
# Processing Record 31 of Set 15 | ngunguru
# Processing Record 32 of Set 15 | prince rupert
# Processing Record 33 of Set 15 | rio grande
# Processing Record 34 of Set 15 | zhigalovo
# Processing Record 35 of Set 15 | kaeo
# Processing Record 36 of Set 15 | vostok
# Processing Record 37 of Set 15 | winslow
# Processing Record 38 of Set 15 | ternate
# Processing Record 39 of Set 15 | finote selam
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# # Add data to new DataFrame

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Kargasok  59.0556   80.8572     17.67        98         100        3.58
# 1   Ushuaia -54.8000  -68.3000     60.46        31          75       19.57
# 2   Iqaluit  63.7506  -68.5145      8.33        78          75        4.00
# 3   Ahipara -35.1667  173.1667     70.48        60         100        4.00
# 4     Hobyo   5.3505   48.5268     79.05        66          73       18.95
#
#   Weather Description                 Date
# 0     overcast clouds  2021-11-30 21:34:11
# 1       broken clouds  2021-11-30 21:29:19
# 2       broken clouds  2021-11-30 21:34:11
# 3     overcast clouds  2021-11-30 21:34:12
# 4       broken clouds  2021-11-30 21:34:13

# %% [markdown]
# # Export DataFrame to CSV

# %%
city_data_df.to_csv('weather_database.csv')
