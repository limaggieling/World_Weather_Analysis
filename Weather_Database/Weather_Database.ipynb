# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import timeit
import random
import time

# import citipy module
from citipy import citipy

# import requests library
import requests

# import api key
from config import weather_api_key

# open weather map starter url and api key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# import datetime module
from datetime import datetime

# %% [markdown]
# # Create a new set of 2,000 random latitudes and longitudes

# %%
# Create set of 2000 random lat/lng combos
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# # Get the nearest city using the citipy module

# %%
# Create list for holding cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
# cities list
cities
# Out:
# ['albany',
#  'qaanaaq',
#  'rikitea',
#  'la paz',
#  'east london',
#  'raymondville',
#  'vaitupu',
#  'turayf',
#  'khatanga',
#  'kathmandu',
#  'xapuri',
#  'new norfolk',
#  'buala',
#  'tuktoyaktuk',
#  'illoqqortoormiut',
#  'hermanus',
#  'hagere selam',
#  'coahuayana',
#  'chabahar',
#  'lata',
#  'iisalmi',
#  'kodiak',
#  'ushuaia',
#  'kosya',
#  'grand river south east',
#  'priladozhskiy',
#  'codrington',
#  'nanortalik',
#  'tessalit',
#  'mar del plata',
#  'mataura',
#  'thompson',
#  'cape town',
#  'klaksvik',
#  'busselton',
#  'bambous virieux',
#  'korla',
#  'nikolskoye',
#  'puerto ayora',
#  'punta arenas',
#  'esperance',
#  'beringovskiy',
#  'katsuura',
#  'guerrero negro',
#  'miranorte',
#  'atuona',
#  'hilo',
#  'attawapiskat',
#  'corrientes',
#  'adre',
#  'porto nacional',
#  'aguimes',
#  'kolimvari',
#  'vaini',
#  'nome',
#  'labuhan',
#  'nizhneyansk',
#  'provideniya',
#  'nouadhibou',
#  'bredasdorp',
#  'sanchor',
#  'haines junction',
#  'atchison',
#  'centralia',
#  'lavrentiya',
#  'newport',
#  'luderitz',
#  'heyang',
#  'port macquarie',
#  'fortuna',
#  'te anau',
#  'bluff',
#  'nabire',
#  'nuuk',
#  'marzuq',
#  'palauig',
#  'butaritari',
#  'lebu',
#  'cherskiy',
#  'mutsu',
#  'saleaula',
#  'dingle',
#  'yellowknife',
#  'fernie',
#  'gravdal',
#  'lorengau',
#  'amderma',
#  'kapaa',
#  'hobart',
#  'vardo',
#  'tasiilaq',
#  'lasa',
#  'kenai',
#  'ancud',
#  'mobaye',
#  'ponta do sol',
#  'sendai',
#  'bani walid',
#  'aracruz',
#  'cabo san lucas',
#  'susanino',
#  'nantucket',
#  'jamestown',
#  'coquimbo',
#  'cidreira',
#  'gander',
#  'palmer',
#  'luanda',
#  'xinzhou',
#  'carnarvon',
#  'cayenne',
#  'hambantota',
#  'nan',
#  'gunjur',
#  'el monte',
#  'barrow',
#  'tiksi',
#  'udachnyy',
#  'chara',
#  'aden',
#  'beyneu',
#  'ust-maya',
#  'kavieng',
#  'hithadhoo',
#  'wageningen',
#  'shelburne',
#  'mahebourg',
#  'norman wells',
#  'victoria',
#  'luganville',
#  'rorvik',
#  'we',
#  'phulabani',
#  'bongandanga',
#  'vila velha',
#  'ambon',
#  'avarua',
#  'petrovskoye',
#  'eucaliptus',
#  'karaul',
#  'popondetta',
#  'kiunga',
#  'ruston',
#  'singaparna',
#  'yulara',
#  'denpasar',
#  'avera',
#  'ifo',
#  'jalu',
#  'airai',
#  'nyurba',
#  'aykhal',
#  'dehloran',
#  'port elizabeth',
#  'magistralnyy',
#  'barmer',
#  'port alfred',
#  'taolanaro',
#  'hasaki',
#  'alice springs',
#  'awjilah',
#  'cap malheureux',
#  'sao jose da coroa grande',
#  'pegnitz',
#  'toyooka',
#  'lagos',
#  'geraldton',
#  'petatlan',
#  'unguia',
#  'samusu',
#  'kaitangata',
#  'ellisras',
#  'stoyba',
#  'saint-philippe',
#  'nanakuli',
#  'saint-pierre',
#  'kuusamo',
#  'belushya guba',
#  'marawi',
#  'souillac',
#  'russell',
#  'porto novo',
#  'port lincoln',
#  'middelkerke',
#  'mehamn',
#  'san patricio',
#  'khash',
#  'fort morgan',
#  'tarakan',
#  'palasa',
#  'cullman',
#  'vestmannaeyjar',
#  'mabay',
#  'elk point',
#  'pevek',
#  'den helder',
#  'arraial do cabo',
#  'bengkulu',
#  'sentyabrskiy',
#  'kingaroy',
#  'andenes',
#  'eureka',
#  'faanui',
#  'saskylakh',
#  'petropavl',
#  'nelson bay',
#  'castro',
#  'severo-kurilsk',
#  'qaqortoq',
#  'flin flon',
#  'chokurdakh',
#  'biak',
#  'anamur',
#  'yeppoon',
#  'tazovskiy',
#  'aksu',
#  'khorramshahr',
#  'aflu',
#  'plattsburgh',
#  'kloulklubed',
#  'mount gambier',
#  'manger',
#  'port hardy',
#  'ciudad bolivar',
#  'ruatoria',
#  'verkhoyansk',
#  'becerril',
#  'liku',
#  'sitka',
#  'arlit',
#  'kommunar',
#  'payo',
#  'gushikawa',
#  'aksarka',
#  'georgetown',
#  'moose factory',
#  'pimenta bueno',
#  'mount isa',
#  'constitucion',
#  'tezu',
#  'lagoa',
#  'leh',
#  'upernavik',
#  'kalawit',
#  'tawnat',
#  'east angus',
#  'taltal',
#  'kindu',
#  'caceres',
#  'chardara',
#  'nauchnyy gorodok',
#  'ribeira grande',
#  'bambanglipuro',
#  'cruzeiro do sul',
#  'clemson',
#  'tvoroyri',
#  'anloga',
#  'calvinia',
#  'igarka',
#  'barentsburg',
#  'iseyin',
#  'ketchikan',
#  'khandyga',
#  'warqla',
#  'ratlam',
#  'salym',
#  'verkhnyaya inta',
#  'taoudenni',
#  'kanniyakumari',
#  'chuy',
#  'bilibino',
#  'nizwa',
#  'lingao',
#  'shahr-e kord',
#  'wenzhou',
#  'sept-iles',
#  'morgantown',
#  'gizo',
#  'jiddah',
#  'ouallam',
#  'londoko',
#  'buqayq',
#  'filadelfia',
#  'surt',
#  'melnikovo',
#  'mandalgovi',
#  'comodoro rivadavia',
#  'randvere',
#  'abu samrah',
#  'tumannyy',
#  'saint anthony',
#  'bacuit',
#  'ati',
#  'san cristobal',
#  'podyuga',
#  'aklavik',
#  'isangel',
#  'amarante do maranhao',
#  'saint george',
#  'barroualie',
#  'kahului',
#  'sungaipenuh',
#  'narsaq',
#  'teahupoo',
#  'los llanos de aridane',
#  'henties bay',
#  'gornopravdinsk',
#  'veraval',
#  'kruisfontein',
#  'sao felix do xingu',
#  'hovd',
#  'kabanjahe',
#  'husavik',
#  'takoradi',
#  'bac lieu',
#  'cumaribo',
#  'bosaso',
#  'tuatapere',
#  'ponta pora',
#  'port hedland',
#  'zhigansk',
#  'tsihombe',
#  'broome',
#  'mys shmidta',
#  'tura',
#  'gravenhurst',
#  'rocha',
#  'berlevag',
#  'santa ines',
#  'krasnoselkup',
#  'santa rosa',
#  'margate',
#  'beloha',
#  'wajima',
#  'the valley',
#  'belyy yar',
#  'bahia honda',
#  'romny',
#  'truro',
#  'zyryanka',
#  'fairview',
#  'wuxue',
#  'bargal',
#  'laranjeiras do sul',
#  'trinidad',
#  'punta alta',
#  'college',
#  'talcahuano',
#  'roma',
#  'mildura',
#  'honningsvag',
#  'devils lake',
#  'kutum',
#  'halifax',
#  'gigmoto',
#  'sao joao da barra',
#  'sinnamary',
#  'laguna',
#  'westport',
#  'waw',
#  'platanos',
#  'bonavista',
#  'saldanha',
#  'iqaluit',
#  'talnakh',
#  'marcona',
#  'nsoko',
#  'stony plain',
#  'pangody',
#  'yurla',
#  'yurga',
#  'batemans bay',
#  'san policarpo',
#  'dikson',
#  'bemidji',
#  'el balyana',
#  'conde',
#  'georgiyevka',
#  'ambilobe',
#  'alofi',
#  'balkhash',
#  'manaquiri',
#  'cuiluan',
#  'la palma',
#  'jinchang',
#  'strezhevoy',
#  'benjamin constant',
#  'plouzane',
#  'coruripe',
#  'neryungri',
#  'mayskiy',
#  'sorland',
#  'alta floresta',
#  'sisimiut',
#  'arman',
#  'richards bay',
#  'khorramabad',
#  'namatanai',
#  'teixoso',
#  'kita',
#  'carutapera',
#  'souris',
#  'aketi',
#  'camacha',
#  'obuasi',
#  'redwater',
#  'pacific grove',
#  'kenora',
#  'tiarei',
#  'fatehabad',
#  'kamenka',
#  'emba',
#  'sarangani',
#  'cam ranh',
#  'puerto leguizamo',
#  'namibe',
#  'jieshi',
#  'ilulissat',
#  'alegrete',
#  'chulman',
#  'satitoa',
#  'san juan',
#  'lloydminster',
#  'saurimo',
#  'evensk',
#  'puerto madryn',
#  'alamosa',
#  'ipixuna',
#  'suclayin',
#  'buin',
#  'koygorodok',
#  'ossora',
#  'tabiauea',
#  'ostrovnoy',
#  'bethel',
#  'moscow',
#  'asfi',
#  'capitao poco',
#  'kulhudhuffushi',
#  'naze',
#  'bay roberts',
#  'la ronge',
#  'ishigaki',
#  'epe',
#  'camana',
#  'dudinka',
#  'veliki preslav',
#  'sola',
#  'grindavik',
#  'changanacheri',
#  'tokur',
#  'tual',
#  'gambo',
#  'merauke',
#  'dharchula',
#  'meulaboh',
#  'san vicente',
#  'tunduru',
#  'copiapo',
#  'sambava',
#  'petropavlovsk-kamchatskiy',
#  'rungata',
#  'zavetnoye',
#  'haicheng',
#  'muros',
#  'turukhansk',
#  'oxelosund',
#  'yenagoa',
#  'umzimvubu',
#  'marsh harbour',
#  'miles city',
#  'egvekinot',
#  'charters towers',
#  'puerto escondido',
#  'bababe',
#  'deputatskiy',
#  'sao filipe',
#  'faya',
#  'balykshi',
#  'mahajanga',
#  'pochutla',
#  'pushkino',
#  'khonuu',
#  'adrar',
#  'biloxi',
#  'lamu',
#  'kiama',
#  'brigantine',
#  'baghdad',
#  'tucumcari',
#  'hirtshals',
#  'meyungs',
#  'bardiyah',
#  'pandan',
#  'tadine',
#  'durban',
#  'clyde river',
#  'cartagena',
#  'svetlyy',
#  'amot',
#  'santana do livramento',
#  'san rafael',
#  'xining',
#  'hamilton',
#  'homer',
#  'pearl',
#  'kawai',
#  'isabela',
#  'la serena',
#  'torit',
#  'middle island',
#  'okhotsk',
#  'yatou',
#  'sechura',
#  'kampot',
#  'da nang',
#  'aksay',
#  'florianopolis',
#  'altus',
#  'walvis bay',
#  'christchurch',
#  'mazatlan',
#  'bhag',
#  'fayaoue',
#  'kalakamati',
#  'umba',
#  'male',
#  'barcelos',
#  'novoseleznevo',
#  'puerto ayacucho',
#  'slave lake',
#  'mungaa',
#  'tigil',
#  'acarau',
#  'dalvik',
#  'banda aceh',
#  'kamenskoye',
#  'lazaro cardenas',
#  'shache',
#  'henderson',
#  'paamiut',
#  'thinadhoo',
#  'belaya gora',
#  'beatrice',
#  'rognan',
#  'jega',
#  'batagay',
#  'quelimane',
#  'dandong',
#  'cloquet',
#  'pitea',
#  'calatayud',
#  'lengshuitan',
#  'hit',
#  'leningradskiy',
#  'noumea',
#  'jumla',
#  'ola',
#  'qinggang',
#  'svetlaya',
#  'moron',
#  'boende',
#  'kapiri mposhi',
#  'armacao dos buzios',
#  'sataua',
#  'pisco',
#  'vostok',
#  'semey',
#  'qarqin',
#  'barawe',
#  'hammerfest',
#  'green river',
#  'ilo',
#  'myitkyina',
#  'lutz',
#  'kirensk',
#  'lompoc',
#  'kondinskoye',
#  'kropotkin',
#  'raudeberg',
#  'pishva',
#  'naranjal',
#  'redmond',
#  'gilazi',
#  'vizinga',
#  'lixourion',
#  'freeport',
#  'afanasyevo',
#  'jijiga',
#  'zaysan',
#  'shimoda',
#  'pangnirtung',
#  'yaan',
#  'phu ly',
#  'bontang',
#  'raga',
#  'iskateley',
#  'northam',
#  'maniitsoq',
#  'vila franca do campo',
#  'zlitan',
#  'graaff-reinet',
#  'candawaga',
#  'lolua',
#  'sioux lookout',
#  'portland',
#  'tiznit',
#  'san quintin',
#  'white rock',
#  'salinas',
#  'boma',
#  'khandbari',
#  'seoul',
#  'cassilandia',
#  'goure',
#  'yanan',
#  'ewa beach',
#  'grand gaube',
#  'tetela de ocampo',
#  'kijabe',
#  'kodinsk',
#  'pinawa',
#  'verkhniye tatyshly',
#  'bathsheba',
#  'tibati',
#  'ambatofinandrahana',
#  'arica',
#  'torbay',
#  'shingu',
#  'ingham',
#  'sorata',
#  'ixtapa',
#  'alihe',
#  'kaeo',
#  'mujiayingzi',
#  'pundaguitan',
#  'cueto',
#  'ponta delgada',
#  'erzin',
#  'buy',
#  'yialos',
#  'yuzhnyy',
#  'jacareacanga',
#  'siteki',
#  'hirara',
#  'naustdal',
#  'sawakin',
#  'kavaratti',
#  'davlekanovo',
#  'abalak',
#  'jining',
#  'mercedes',
#  'big rapids',
#  'ures',
#  'amapa',
#  'berdigestyakh',
#  'mosquera',
#  'umm lajj',
#  'beruni',
#  'betsiamites',
#  'mizan teferi',
#  'najran',
#  'fairbanks',
#  'praya',
#  'kastamonu',
#  'pasni',
#  'kawalu',
#  'anadyr',
#  'hede',
#  'labelle',
#  'kozhva',
#  'bowen',
#  'plettenberg bay',
#  'soyo',
#  'garowe',
#  'gazojak',
#  'mayo',
#  'karasburg',
#  'ponnani',
#  'manaure',
#  'newberry',
#  'muroto',
#  'kalemie',
#  'puerto carreno',
#  'bignona',
#  'mezen',
#  'port augusta',
#  'eloy',
#  'pozo colorado',
#  'hirado',
#  'sobolevo',
#  'juneau',
#  'castlemaine',
#  'imbituba',
#  'ikwiriri',
#  'tautira',
#  'inta',
#  'aasiaat',
#  'smithers',
#  'roald',
#  'sungairaya',
#  'letychiv',
#  'amahai',
#  'sorochinsk',
#  'sovetskiy',
#  'puerto suarez',
#  'vila do maio',
#  'matara',
#  'pathein',
#  'concepcion del uruguay',
#  'portadown',
#  'mundra',
#  'fuerte olimpo',
#  'darhan',
#  'huoqiu',
#  'aksarayskiy',
#  'marienburg',
#  'dunedin',
#  'khingansk',
#  'oildale',
#  'bilma',
#  'komsomolskiy',
#  'pekalongan',
#  'galiwinku',
#  'mukhen',
#  'franca',
#  'bundaberg',
#  'colquechaca',
#  'mayumba',
#  'carinhanha',
#  'oshawa',
#  'aswan',
#  'along',
#  'carbonia',
#  'alyangula',
#  'valley city',
#  'daniel flores',
#  'pilao arcado',
#  'baykit',
#  'keuruu',
#  'bafq',
#  'znamenskoye',
#  'kyren',
#  'pitimbu',
#  'inongo',
#  'szczytno',
#  'shiyan',
#  'beihai',
#  'gat',
#  'mergui',
#  'bosobolo',
#  'nemuro',
#  'terney',
#  'monchegorsk',
#  'anori',
#  'kijang',
#  'nauta',
#  'tarusa',
#  'ndjole',
#  'bandundu']

# %% [markdown]
# # Perform an API Call with OpenWeatherMap

# %%
# create empty list to hold city weather data
city_data = []

# print beginning of logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# create counters to see progress
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %% [markdown]
# # Retrieve lat/lng, max temp, %humidity, %cloudiness, wind speed, weather description

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weatherDescription = city_weather['weather'][0]['description']
        city_country = city_weather['sys']['country']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_weatherDescription,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("error")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | la paz
# Processing Record 5 of Set 1 | east london
# Processing Record 6 of Set 1 | raymondville
# Processing Record 7 of Set 1 | vaitupu
# error
# Processing Record 8 of Set 1 | turayf
# Processing Record 9 of Set 1 | khatanga
# Processing Record 10 of Set 1 | kathmandu
# Processing Record 11 of Set 1 | xapuri
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | buala
# Processing Record 14 of Set 1 | tuktoyaktuk
# Processing Record 15 of Set 1 | illoqqortoormiut
# error
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | hagere selam
# Processing Record 18 of Set 1 | coahuayana
# Processing Record 19 of Set 1 | chabahar
# Processing Record 20 of Set 1 | lata
# Processing Record 21 of Set 1 | iisalmi
# Processing Record 22 of Set 1 | kodiak
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | kosya
# error
# Processing Record 25 of Set 1 | grand river south east
# error
# Processing Record 26 of Set 1 | priladozhskiy
# Processing Record 27 of Set 1 | codrington
# Processing Record 28 of Set 1 | nanortalik
# Processing Record 29 of Set 1 | tessalit
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | klaksvik
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | bambous virieux
# Processing Record 37 of Set 1 | korla
# Processing Record 38 of Set 1 | nikolskoye
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | esperance
# Processing Record 42 of Set 1 | beringovskiy
# Processing Record 43 of Set 1 | katsuura
# Processing Record 44 of Set 1 | guerrero negro
# Processing Record 45 of Set 1 | miranorte
# error
# Processing Record 46 of Set 1 | atuona
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | attawapiskat
# error
# Processing Record 49 of Set 1 | corrientes
# Processing Record 50 of Set 1 | adre
# Processing Record 1 of Set 2 | porto nacional
# Processing Record 2 of Set 2 | aguimes
# Processing Record 3 of Set 2 | kolimvari
# error
# Processing Record 4 of Set 2 | vaini
# Processing Record 5 of Set 2 | nome
# Processing Record 6 of Set 2 | labuhan
# Processing Record 7 of Set 2 | nizhneyansk
# error
# Processing Record 8 of Set 2 | provideniya
# Processing Record 9 of Set 2 | nouadhibou
# Processing Record 10 of Set 2 | bredasdorp
# Processing Record 11 of Set 2 | sanchor
# Processing Record 12 of Set 2 | haines junction
# Processing Record 13 of Set 2 | atchison
# Processing Record 14 of Set 2 | centralia
# Processing Record 15 of Set 2 | lavrentiya
# Processing Record 16 of Set 2 | newport
# Processing Record 17 of Set 2 | luderitz
# Processing Record 18 of Set 2 | heyang
# Processing Record 19 of Set 2 | port macquarie
# Processing Record 20 of Set 2 | fortuna
# Processing Record 21 of Set 2 | te anau
# Processing Record 22 of Set 2 | bluff
# Processing Record 23 of Set 2 | nabire
# Processing Record 24 of Set 2 | nuuk
# Processing Record 25 of Set 2 | marzuq
# Processing Record 26 of Set 2 | palauig
# Processing Record 27 of Set 2 | butaritari
# Processing Record 28 of Set 2 | lebu
# Processing Record 29 of Set 2 | cherskiy
# Processing Record 30 of Set 2 | mutsu
# Processing Record 31 of Set 2 | saleaula
# error
# Processing Record 32 of Set 2 | dingle
# Processing Record 33 of Set 2 | yellowknife
# Processing Record 34 of Set 2 | fernie
# Processing Record 35 of Set 2 | gravdal
# Processing Record 36 of Set 2 | lorengau
# Processing Record 37 of Set 2 | amderma
# error
# Processing Record 38 of Set 2 | kapaa
# Processing Record 39 of Set 2 | hobart
# Processing Record 40 of Set 2 | vardo
# Processing Record 41 of Set 2 | tasiilaq
# Processing Record 42 of Set 2 | lasa
# Processing Record 43 of Set 2 | kenai
# Processing Record 44 of Set 2 | ancud
# Processing Record 45 of Set 2 | mobaye
# Processing Record 46 of Set 2 | ponta do sol
# Processing Record 47 of Set 2 | sendai
# Processing Record 48 of Set 2 | bani walid
# Processing Record 49 of Set 2 | aracruz
# Processing Record 50 of Set 2 | cabo san lucas
# Processing Record 1 of Set 3 | susanino
# Processing Record 2 of Set 3 | nantucket
# Processing Record 3 of Set 3 | jamestown
# Processing Record 4 of Set 3 | coquimbo
# Processing Record 5 of Set 3 | cidreira
# Processing Record 6 of Set 3 | gander
# Processing Record 7 of Set 3 | palmer
# Processing Record 8 of Set 3 | luanda
# Processing Record 9 of Set 3 | xinzhou
# Processing Record 10 of Set 3 | carnarvon
# Processing Record 11 of Set 3 | cayenne
# Processing Record 12 of Set 3 | hambantota
# Processing Record 13 of Set 3 | nan
# Processing Record 14 of Set 3 | gunjur
# Processing Record 15 of Set 3 | el monte
# Processing Record 16 of Set 3 | barrow
# Processing Record 17 of Set 3 | tiksi
# Processing Record 18 of Set 3 | udachnyy
# Processing Record 19 of Set 3 | chara
# Processing Record 20 of Set 3 | aden
# Processing Record 21 of Set 3 | beyneu
# Processing Record 22 of Set 3 | ust-maya
# Processing Record 23 of Set 3 | kavieng
# Processing Record 24 of Set 3 | hithadhoo
# Processing Record 25 of Set 3 | wageningen
# Processing Record 26 of Set 3 | shelburne
# Processing Record 27 of Set 3 | mahebourg
# Processing Record 28 of Set 3 | norman wells
# Processing Record 29 of Set 3 | victoria
# Processing Record 30 of Set 3 | luganville
# Processing Record 31 of Set 3 | rorvik
# Processing Record 32 of Set 3 | we
# error
# Processing Record 33 of Set 3 | phulabani
# Processing Record 34 of Set 3 | bongandanga
# Processing Record 35 of Set 3 | vila velha
# Processing Record 36 of Set 3 | ambon
# Processing Record 37 of Set 3 | avarua
# Processing Record 38 of Set 3 | petrovskoye
# Processing Record 39 of Set 3 | eucaliptus
# Processing Record 40 of Set 3 | karaul
# error
# Processing Record 41 of Set 3 | popondetta
# Processing Record 42 of Set 3 | kiunga
# Processing Record 43 of Set 3 | ruston
# Processing Record 44 of Set 3 | singaparna
# Processing Record 45 of Set 3 | yulara
# Processing Record 46 of Set 3 | denpasar
# Processing Record 47 of Set 3 | avera
# Processing Record 48 of Set 3 | ifo
# Processing Record 49 of Set 3 | jalu
# Processing Record 50 of Set 3 | airai
# Processing Record 1 of Set 4 | nyurba
# Processing Record 2 of Set 4 | aykhal
# Processing Record 3 of Set 4 | dehloran
# Processing Record 4 of Set 4 | port elizabeth
# Processing Record 5 of Set 4 | magistralnyy
# Processing Record 6 of Set 4 | barmer
# Processing Record 7 of Set 4 | port alfred
# Processing Record 8 of Set 4 | taolanaro
# error
# Processing Record 9 of Set 4 | hasaki
# Processing Record 10 of Set 4 | alice springs
# Processing Record 11 of Set 4 | awjilah
# Processing Record 12 of Set 4 | cap malheureux
# Processing Record 13 of Set 4 | sao jose da coroa grande
# Processing Record 14 of Set 4 | pegnitz
# Processing Record 15 of Set 4 | toyooka
# Processing Record 16 of Set 4 | lagos
# Processing Record 17 of Set 4 | geraldton
# Processing Record 18 of Set 4 | petatlan
# Processing Record 19 of Set 4 | unguia
# Processing Record 20 of Set 4 | samusu
# error
# Processing Record 21 of Set 4 | kaitangata
# Processing Record 22 of Set 4 | ellisras
# Processing Record 23 of Set 4 | stoyba
# error
# Processing Record 24 of Set 4 | saint-philippe
# Processing Record 25 of Set 4 | nanakuli
# Processing Record 26 of Set 4 | saint-pierre
# Processing Record 27 of Set 4 | kuusamo
# Processing Record 28 of Set 4 | belushya guba
# error
# Processing Record 29 of Set 4 | marawi
# Processing Record 30 of Set 4 | souillac
# Processing Record 31 of Set 4 | russell
# Processing Record 32 of Set 4 | porto novo
# Processing Record 33 of Set 4 | port lincoln
# Processing Record 34 of Set 4 | middelkerke
# Processing Record 35 of Set 4 | mehamn
# Processing Record 36 of Set 4 | san patricio
# Processing Record 37 of Set 4 | khash
# Processing Record 38 of Set 4 | fort morgan
# Processing Record 39 of Set 4 | tarakan
# Processing Record 40 of Set 4 | palasa
# Processing Record 41 of Set 4 | cullman
# Processing Record 42 of Set 4 | vestmannaeyjar
# Processing Record 43 of Set 4 | mabay
# Processing Record 44 of Set 4 | elk point
# Processing Record 45 of Set 4 | pevek
# Processing Record 46 of Set 4 | den helder
# Processing Record 47 of Set 4 | arraial do cabo
# Processing Record 48 of Set 4 | bengkulu
# Processing Record 49 of Set 4 | sentyabrskiy
# error
# Processing Record 50 of Set 4 | kingaroy
# Processing Record 1 of Set 5 | andenes
# Processing Record 2 of Set 5 | eureka
# Processing Record 3 of Set 5 | faanui
# Processing Record 4 of Set 5 | saskylakh
# Processing Record 5 of Set 5 | petropavl
# Processing Record 6 of Set 5 | nelson bay
# Processing Record 7 of Set 5 | castro
# Processing Record 8 of Set 5 | severo-kurilsk
# Processing Record 9 of Set 5 | qaqortoq
# Processing Record 10 of Set 5 | flin flon
# Processing Record 11 of Set 5 | chokurdakh
# Processing Record 12 of Set 5 | biak
# Processing Record 13 of Set 5 | anamur
# Processing Record 14 of Set 5 | yeppoon
# Processing Record 15 of Set 5 | tazovskiy
# Processing Record 16 of Set 5 | aksu
# Processing Record 17 of Set 5 | khorramshahr
# Processing Record 18 of Set 5 | aflu
# error
# Processing Record 19 of Set 5 | plattsburgh
# Processing Record 20 of Set 5 | kloulklubed
# Processing Record 21 of Set 5 | mount gambier
# Processing Record 22 of Set 5 | manger
# Processing Record 23 of Set 5 | port hardy
# Processing Record 24 of Set 5 | ciudad bolivar
# Processing Record 25 of Set 5 | ruatoria
# error
# Processing Record 26 of Set 5 | verkhoyansk
# Processing Record 27 of Set 5 | becerril
# Processing Record 28 of Set 5 | liku
# Processing Record 29 of Set 5 | sitka
# Processing Record 30 of Set 5 | arlit
# Processing Record 31 of Set 5 | kommunar
# Processing Record 32 of Set 5 | payo
# Processing Record 33 of Set 5 | gushikawa
# Processing Record 34 of Set 5 | aksarka
# Processing Record 35 of Set 5 | georgetown
# Processing Record 36 of Set 5 | moose factory
# Processing Record 37 of Set 5 | pimenta bueno
# Processing Record 38 of Set 5 | mount isa
# Processing Record 39 of Set 5 | constitucion
# Processing Record 40 of Set 5 | tezu
# Processing Record 41 of Set 5 | lagoa
# Processing Record 42 of Set 5 | leh
# Processing Record 43 of Set 5 | upernavik
# Processing Record 44 of Set 5 | kalawit
# Processing Record 45 of Set 5 | tawnat
# error
# Processing Record 46 of Set 5 | east angus
# Processing Record 47 of Set 5 | taltal
# Processing Record 48 of Set 5 | kindu
# Processing Record 49 of Set 5 | caceres
# Processing Record 50 of Set 5 | chardara
# Processing Record 1 of Set 6 | nauchnyy gorodok
# Processing Record 2 of Set 6 | ribeira grande
# Processing Record 3 of Set 6 | bambanglipuro
# Processing Record 4 of Set 6 | cruzeiro do sul
# Processing Record 5 of Set 6 | clemson
# Processing Record 6 of Set 6 | tvoroyri
# Processing Record 7 of Set 6 | anloga
# Processing Record 8 of Set 6 | calvinia
# Processing Record 9 of Set 6 | igarka
# Processing Record 10 of Set 6 | barentsburg
# error
# Processing Record 11 of Set 6 | iseyin
# Processing Record 12 of Set 6 | ketchikan
# Processing Record 13 of Set 6 | khandyga
# Processing Record 14 of Set 6 | warqla
# error
# Processing Record 15 of Set 6 | ratlam
# Processing Record 16 of Set 6 | salym
# Processing Record 17 of Set 6 | verkhnyaya inta
# Processing Record 18 of Set 6 | taoudenni
# Processing Record 19 of Set 6 | kanniyakumari
# Processing Record 20 of Set 6 | chuy
# Processing Record 21 of Set 6 | bilibino
# Processing Record 22 of Set 6 | nizwa
# Processing Record 23 of Set 6 | lingao
# Processing Record 24 of Set 6 | shahr-e kord
# Processing Record 25 of Set 6 | wenzhou
# Processing Record 26 of Set 6 | sept-iles
# Processing Record 27 of Set 6 | morgantown
# Processing Record 28 of Set 6 | gizo
# Processing Record 29 of Set 6 | jiddah
# error
# Processing Record 30 of Set 6 | ouallam
# Processing Record 31 of Set 6 | londoko
# Processing Record 32 of Set 6 | buqayq
# error
# Processing Record 33 of Set 6 | filadelfia
# Processing Record 34 of Set 6 | surt
# Processing Record 35 of Set 6 | melnikovo
# Processing Record 36 of Set 6 | mandalgovi
# Processing Record 37 of Set 6 | comodoro rivadavia
# Processing Record 38 of Set 6 | randvere
# error
# Processing Record 39 of Set 6 | abu samrah
# Processing Record 40 of Set 6 | tumannyy
# error
# Processing Record 41 of Set 6 | saint anthony
# Processing Record 42 of Set 6 | bacuit
# error
# Processing Record 43 of Set 6 | ati
# Processing Record 44 of Set 6 | san cristobal
# Processing Record 45 of Set 6 | podyuga
# Processing Record 46 of Set 6 | aklavik
# Processing Record 47 of Set 6 | isangel
# Processing Record 48 of Set 6 | amarante do maranhao
# Processing Record 49 of Set 6 | saint george
# Processing Record 50 of Set 6 | barroualie
# error
# Processing Record 1 of Set 7 | kahului
# Processing Record 2 of Set 7 | sungaipenuh
# Processing Record 3 of Set 7 | narsaq
# Processing Record 4 of Set 7 | teahupoo
# Processing Record 5 of Set 7 | los llanos de aridane
# Processing Record 6 of Set 7 | henties bay
# Processing Record 7 of Set 7 | gornopravdinsk
# Processing Record 8 of Set 7 | veraval
# Processing Record 9 of Set 7 | kruisfontein
# Processing Record 10 of Set 7 | sao felix do xingu
# Processing Record 11 of Set 7 | hovd
# Processing Record 12 of Set 7 | kabanjahe
# Processing Record 13 of Set 7 | husavik
# Processing Record 14 of Set 7 | takoradi
# Processing Record 15 of Set 7 | bac lieu
# Processing Record 16 of Set 7 | cumaribo
# error
# Processing Record 17 of Set 7 | bosaso
# Processing Record 18 of Set 7 | tuatapere
# Processing Record 19 of Set 7 | ponta pora
# Processing Record 20 of Set 7 | port hedland
# Processing Record 21 of Set 7 | zhigansk
# Processing Record 22 of Set 7 | tsihombe
# error
# Processing Record 23 of Set 7 | broome
# Processing Record 24 of Set 7 | mys shmidta
# error
# Processing Record 25 of Set 7 | tura
# Processing Record 26 of Set 7 | gravenhurst
# Processing Record 27 of Set 7 | rocha
# Processing Record 28 of Set 7 | berlevag
# Processing Record 29 of Set 7 | santa ines
# Processing Record 30 of Set 7 | krasnoselkup
# Processing Record 31 of Set 7 | santa rosa
# Processing Record 32 of Set 7 | margate
# Processing Record 33 of Set 7 | beloha
# Processing Record 34 of Set 7 | wajima
# Processing Record 35 of Set 7 | the valley
# Processing Record 36 of Set 7 | belyy yar
# Processing Record 37 of Set 7 | bahia honda
# Processing Record 38 of Set 7 | romny
# Processing Record 39 of Set 7 | truro
# Processing Record 40 of Set 7 | zyryanka
# Processing Record 41 of Set 7 | fairview
# Processing Record 42 of Set 7 | wuxue
# Processing Record 43 of Set 7 | bargal
# error
# Processing Record 44 of Set 7 | laranjeiras do sul
# Processing Record 45 of Set 7 | trinidad
# Processing Record 46 of Set 7 | punta alta
# Processing Record 47 of Set 7 | college
# Processing Record 48 of Set 7 | talcahuano
# Processing Record 49 of Set 7 | roma
# Processing Record 50 of Set 7 | mildura
# Processing Record 1 of Set 8 | honningsvag
# Processing Record 2 of Set 8 | devils lake
# Processing Record 3 of Set 8 | kutum
# Processing Record 4 of Set 8 | halifax
# Processing Record 5 of Set 8 | gigmoto
# Processing Record 6 of Set 8 | sao joao da barra
# Processing Record 7 of Set 8 | sinnamary
# Processing Record 8 of Set 8 | laguna
# Processing Record 9 of Set 8 | westport
# Processing Record 10 of Set 8 | waw
# Processing Record 11 of Set 8 | platanos
# Processing Record 12 of Set 8 | bonavista
# Processing Record 13 of Set 8 | saldanha
# Processing Record 14 of Set 8 | iqaluit
# Processing Record 15 of Set 8 | talnakh
# Processing Record 16 of Set 8 | marcona
# error
# Processing Record 17 of Set 8 | nsoko
# Processing Record 18 of Set 8 | stony plain
# Processing Record 19 of Set 8 | pangody
# Processing Record 20 of Set 8 | yurla
# Processing Record 21 of Set 8 | yurga
# Processing Record 22 of Set 8 | batemans bay
# Processing Record 23 of Set 8 | san policarpo
# Processing Record 24 of Set 8 | dikson
# Processing Record 25 of Set 8 | bemidji
# Processing Record 26 of Set 8 | el balyana
# error
# Processing Record 27 of Set 8 | conde
# Processing Record 28 of Set 8 | georgiyevka
# Processing Record 29 of Set 8 | ambilobe
# Processing Record 30 of Set 8 | alofi
# Processing Record 31 of Set 8 | balkhash
# Processing Record 32 of Set 8 | manaquiri
# Processing Record 33 of Set 8 | cuiluan
# Processing Record 34 of Set 8 | la palma
# Processing Record 35 of Set 8 | jinchang
# Processing Record 36 of Set 8 | strezhevoy
# Processing Record 37 of Set 8 | benjamin constant
# Processing Record 38 of Set 8 | plouzane
# Processing Record 39 of Set 8 | coruripe
# Processing Record 40 of Set 8 | neryungri
# Processing Record 41 of Set 8 | mayskiy
# Processing Record 42 of Set 8 | sorland
# Processing Record 43 of Set 8 | alta floresta
# Processing Record 44 of Set 8 | sisimiut
# Processing Record 45 of Set 8 | arman
# Processing Record 46 of Set 8 | richards bay
# Processing Record 47 of Set 8 | khorramabad
# Processing Record 48 of Set 8 | namatanai
# Processing Record 49 of Set 8 | teixoso
# Processing Record 50 of Set 8 | kita
# Processing Record 1 of Set 9 | carutapera
# Processing Record 2 of Set 9 | souris
# Processing Record 3 of Set 9 | aketi
# Processing Record 4 of Set 9 | camacha
# Processing Record 5 of Set 9 | obuasi
# Processing Record 6 of Set 9 | redwater
# Processing Record 7 of Set 9 | pacific grove
# Processing Record 8 of Set 9 | kenora
# Processing Record 9 of Set 9 | tiarei
# Processing Record 10 of Set 9 | fatehabad
# Processing Record 11 of Set 9 | kamenka
# Processing Record 12 of Set 9 | emba
# Processing Record 13 of Set 9 | sarangani
# Processing Record 14 of Set 9 | cam ranh
# Processing Record 15 of Set 9 | puerto leguizamo
# Processing Record 16 of Set 9 | namibe
# Processing Record 17 of Set 9 | jieshi
# Processing Record 18 of Set 9 | ilulissat
# Processing Record 19 of Set 9 | alegrete
# Processing Record 20 of Set 9 | chulman
# Processing Record 21 of Set 9 | satitoa
# error
# Processing Record 22 of Set 9 | san juan
# Processing Record 23 of Set 9 | lloydminster
# Processing Record 24 of Set 9 | saurimo
# Processing Record 25 of Set 9 | evensk
# Processing Record 26 of Set 9 | puerto madryn
# Processing Record 27 of Set 9 | alamosa
# Processing Record 28 of Set 9 | ipixuna
# Processing Record 29 of Set 9 | suclayin
# Processing Record 30 of Set 9 | buin
# Processing Record 31 of Set 9 | koygorodok
# Processing Record 32 of Set 9 | ossora
# Processing Record 33 of Set 9 | tabiauea
# error
# Processing Record 34 of Set 9 | ostrovnoy
# Processing Record 35 of Set 9 | bethel
# Processing Record 36 of Set 9 | moscow
# Processing Record 37 of Set 9 | asfi
# Processing Record 38 of Set 9 | capitao poco
# Processing Record 39 of Set 9 | kulhudhuffushi
# Processing Record 40 of Set 9 | naze
# Processing Record 41 of Set 9 | bay roberts
# Processing Record 42 of Set 9 | la ronge
# Processing Record 43 of Set 9 | ishigaki
# Processing Record 44 of Set 9 | epe
# Processing Record 45 of Set 9 | camana
# Processing Record 46 of Set 9 | dudinka
# Processing Record 47 of Set 9 | veliki preslav
# Processing Record 48 of Set 9 | sola
# Processing Record 49 of Set 9 | grindavik
# Processing Record 50 of Set 9 | changanacheri
# Processing Record 1 of Set 10 | tokur
# Processing Record 2 of Set 10 | tual
# Processing Record 3 of Set 10 | gambo
# Processing Record 4 of Set 10 | merauke
# Processing Record 5 of Set 10 | dharchula
# Processing Record 6 of Set 10 | meulaboh
# Processing Record 7 of Set 10 | san vicente
# Processing Record 8 of Set 10 | tunduru
# error
# Processing Record 9 of Set 10 | copiapo
# Processing Record 10 of Set 10 | sambava
# Processing Record 11 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 10 | rungata
# error
# Processing Record 13 of Set 10 | zavetnoye
# Processing Record 14 of Set 10 | haicheng
# Processing Record 15 of Set 10 | muros
# Processing Record 16 of Set 10 | turukhansk
# Processing Record 17 of Set 10 | oxelosund
# Processing Record 18 of Set 10 | yenagoa
# Processing Record 19 of Set 10 | umzimvubu
# error
# Processing Record 20 of Set 10 | marsh harbour
# Processing Record 21 of Set 10 | miles city
# Processing Record 22 of Set 10 | egvekinot
# Processing Record 23 of Set 10 | charters towers
# Processing Record 24 of Set 10 | puerto escondido
# Processing Record 25 of Set 10 | bababe
# error
# Processing Record 26 of Set 10 | deputatskiy
# Processing Record 27 of Set 10 | sao filipe
# Processing Record 28 of Set 10 | faya
# Processing Record 29 of Set 10 | balykshi
# Processing Record 30 of Set 10 | mahajanga
# Processing Record 31 of Set 10 | pochutla
# Processing Record 32 of Set 10 | pushkino
# Processing Record 33 of Set 10 | khonuu
# error
# Processing Record 34 of Set 10 | adrar
# Processing Record 35 of Set 10 | biloxi
# Processing Record 36 of Set 10 | lamu
# Processing Record 37 of Set 10 | kiama
# Processing Record 38 of Set 10 | brigantine
# Processing Record 39 of Set 10 | baghdad
# Processing Record 40 of Set 10 | tucumcari
# Processing Record 41 of Set 10 | hirtshals
# Processing Record 42 of Set 10 | meyungs
# error
# Processing Record 43 of Set 10 | bardiyah
# Processing Record 44 of Set 10 | pandan
# Processing Record 45 of Set 10 | tadine
# Processing Record 46 of Set 10 | durban
# Processing Record 47 of Set 10 | clyde river
# Processing Record 48 of Set 10 | cartagena
# Processing Record 49 of Set 10 | svetlyy
# Processing Record 50 of Set 10 | amot
# Processing Record 1 of Set 11 | santana do livramento
# Processing Record 2 of Set 11 | san rafael
# Processing Record 3 of Set 11 | xining
# Processing Record 4 of Set 11 | hamilton
# Processing Record 5 of Set 11 | homer
# Processing Record 6 of Set 11 | pearl
# Processing Record 7 of Set 11 | kawai
# Processing Record 8 of Set 11 | isabela
# Processing Record 9 of Set 11 | la serena
# Processing Record 10 of Set 11 | torit
# Processing Record 11 of Set 11 | middle island
# Processing Record 12 of Set 11 | okhotsk
# Processing Record 13 of Set 11 | yatou
# Processing Record 14 of Set 11 | sechura
# Processing Record 15 of Set 11 | kampot
# Processing Record 16 of Set 11 | da nang
# Processing Record 17 of Set 11 | aksay
# Processing Record 18 of Set 11 | florianopolis
# Processing Record 19 of Set 11 | altus
# Processing Record 20 of Set 11 | walvis bay
# Processing Record 21 of Set 11 | christchurch
# Processing Record 22 of Set 11 | mazatlan
# Processing Record 23 of Set 11 | bhag
# Processing Record 24 of Set 11 | fayaoue
# Processing Record 25 of Set 11 | kalakamati
# Processing Record 26 of Set 11 | umba
# Processing Record 27 of Set 11 | male
# Processing Record 28 of Set 11 | barcelos
# Processing Record 29 of Set 11 | novoseleznevo
# Processing Record 30 of Set 11 | puerto ayacucho
# Processing Record 31 of Set 11 | slave lake
# Processing Record 32 of Set 11 | mungaa
# Processing Record 33 of Set 11 | tigil
# Processing Record 34 of Set 11 | acarau
# Processing Record 35 of Set 11 | dalvik
# Processing Record 36 of Set 11 | banda aceh
# Processing Record 37 of Set 11 | kamenskoye
# error
# Processing Record 38 of Set 11 | lazaro cardenas
# Processing Record 39 of Set 11 | shache
# Processing Record 40 of Set 11 | henderson
# Processing Record 41 of Set 11 | paamiut
# Processing Record 42 of Set 11 | thinadhoo
# Processing Record 43 of Set 11 | belaya gora
# Processing Record 44 of Set 11 | beatrice
# Processing Record 45 of Set 11 | rognan
# Processing Record 46 of Set 11 | jega
# Processing Record 47 of Set 11 | batagay
# Processing Record 48 of Set 11 | quelimane
# Processing Record 49 of Set 11 | dandong
# Processing Record 50 of Set 11 | cloquet
# Processing Record 1 of Set 12 | pitea
# Processing Record 2 of Set 12 | calatayud
# Processing Record 3 of Set 12 | lengshuitan
# Processing Record 4 of Set 12 | hit
# Processing Record 5 of Set 12 | leningradskiy
# Processing Record 6 of Set 12 | noumea
# Processing Record 7 of Set 12 | jumla
# Processing Record 8 of Set 12 | ola
# Processing Record 9 of Set 12 | qinggang
# Processing Record 10 of Set 12 | svetlaya
# Processing Record 11 of Set 12 | moron
# Processing Record 12 of Set 12 | boende
# Processing Record 13 of Set 12 | kapiri mposhi
# Processing Record 14 of Set 12 | armacao dos buzios
# error
# Processing Record 15 of Set 12 | sataua
# error
# Processing Record 16 of Set 12 | pisco
# Processing Record 17 of Set 12 | vostok
# Processing Record 18 of Set 12 | semey
# Processing Record 19 of Set 12 | qarqin
# Processing Record 20 of Set 12 | barawe
# error
# Processing Record 21 of Set 12 | hammerfest
# Processing Record 22 of Set 12 | green river
# Processing Record 23 of Set 12 | ilo
# Processing Record 24 of Set 12 | myitkyina
# Processing Record 25 of Set 12 | lutz
# Processing Record 26 of Set 12 | kirensk
# Processing Record 27 of Set 12 | lompoc
# Processing Record 28 of Set 12 | kondinskoye
# Processing Record 29 of Set 12 | kropotkin
# Processing Record 30 of Set 12 | raudeberg
# Processing Record 31 of Set 12 | pishva
# Processing Record 32 of Set 12 | naranjal
# Processing Record 33 of Set 12 | redmond
# Processing Record 34 of Set 12 | gilazi
# error
# Processing Record 35 of Set 12 | vizinga
# Processing Record 36 of Set 12 | lixourion
# Processing Record 37 of Set 12 | freeport
# Processing Record 38 of Set 12 | afanasyevo
# error
# Processing Record 39 of Set 12 | jijiga
# Processing Record 40 of Set 12 | zaysan
# Processing Record 41 of Set 12 | shimoda
# Processing Record 42 of Set 12 | pangnirtung
# Processing Record 43 of Set 12 | yaan
# Processing Record 44 of Set 12 | phu ly
# Processing Record 45 of Set 12 | bontang
# Processing Record 46 of Set 12 | raga
# Processing Record 47 of Set 12 | iskateley
# Processing Record 48 of Set 12 | northam
# Processing Record 49 of Set 12 | maniitsoq
# Processing Record 50 of Set 12 | vila franca do campo
# Processing Record 1 of Set 13 | zlitan
# Processing Record 2 of Set 13 | graaff-reinet
# Processing Record 3 of Set 13 | candawaga
# error
# Processing Record 4 of Set 13 | lolua
# error
# Processing Record 5 of Set 13 | sioux lookout
# Processing Record 6 of Set 13 | portland
# Processing Record 7 of Set 13 | tiznit
# Processing Record 8 of Set 13 | san quintin
# Processing Record 9 of Set 13 | white rock
# Processing Record 10 of Set 13 | salinas
# Processing Record 11 of Set 13 | boma
# Processing Record 12 of Set 13 | khandbari
# Processing Record 13 of Set 13 | seoul
# Processing Record 14 of Set 13 | cassilandia
# Processing Record 15 of Set 13 | goure
# Processing Record 16 of Set 13 | yanan
# error
# Processing Record 17 of Set 13 | ewa beach
# Processing Record 18 of Set 13 | grand gaube
# Processing Record 19 of Set 13 | tetela de ocampo
# Processing Record 20 of Set 13 | kijabe
# Processing Record 21 of Set 13 | kodinsk
# Processing Record 22 of Set 13 | pinawa
# Processing Record 23 of Set 13 | verkhniye tatyshly
# Processing Record 24 of Set 13 | bathsheba
# Processing Record 25 of Set 13 | tibati
# Processing Record 26 of Set 13 | ambatofinandrahana
# Processing Record 27 of Set 13 | arica
# Processing Record 28 of Set 13 | torbay
# Processing Record 29 of Set 13 | shingu
# Processing Record 30 of Set 13 | ingham
# Processing Record 31 of Set 13 | sorata
# Processing Record 32 of Set 13 | ixtapa
# Processing Record 33 of Set 13 | alihe
# Processing Record 34 of Set 13 | kaeo
# Processing Record 35 of Set 13 | mujiayingzi
# Processing Record 36 of Set 13 | pundaguitan
# Processing Record 37 of Set 13 | cueto
# Processing Record 38 of Set 13 | ponta delgada
# Processing Record 39 of Set 13 | erzin
# Processing Record 40 of Set 13 | buy
# Processing Record 41 of Set 13 | yialos
# error
# Processing Record 42 of Set 13 | yuzhnyy
# Processing Record 43 of Set 13 | jacareacanga
# Processing Record 44 of Set 13 | siteki
# Processing Record 45 of Set 13 | hirara
# Processing Record 46 of Set 13 | naustdal
# Processing Record 47 of Set 13 | sawakin
# Processing Record 48 of Set 13 | kavaratti
# Processing Record 49 of Set 13 | davlekanovo
# Processing Record 50 of Set 13 | abalak
# Processing Record 1 of Set 14 | jining
# Processing Record 2 of Set 14 | mercedes
# Processing Record 3 of Set 14 | big rapids
# Processing Record 4 of Set 14 | ures
# Processing Record 5 of Set 14 | amapa
# Processing Record 6 of Set 14 | berdigestyakh
# Processing Record 7 of Set 14 | mosquera
# Processing Record 8 of Set 14 | umm lajj
# Processing Record 9 of Set 14 | beruni
# error
# Processing Record 10 of Set 14 | betsiamites
# Processing Record 11 of Set 14 | mizan teferi
# Processing Record 12 of Set 14 | najran
# Processing Record 13 of Set 14 | fairbanks
# Processing Record 14 of Set 14 | praya
# Processing Record 15 of Set 14 | kastamonu
# Processing Record 16 of Set 14 | pasni
# Processing Record 17 of Set 14 | kawalu
# Processing Record 18 of Set 14 | anadyr
# Processing Record 19 of Set 14 | hede
# Processing Record 20 of Set 14 | labelle
# Processing Record 21 of Set 14 | kozhva
# Processing Record 22 of Set 14 | bowen
# Processing Record 23 of Set 14 | plettenberg bay
# Processing Record 24 of Set 14 | soyo
# Processing Record 25 of Set 14 | garowe
# Processing Record 26 of Set 14 | gazojak
# Processing Record 27 of Set 14 | mayo
# Processing Record 28 of Set 14 | karasburg
# Processing Record 29 of Set 14 | ponnani
# Processing Record 30 of Set 14 | manaure
# Processing Record 31 of Set 14 | newberry
# Processing Record 32 of Set 14 | muroto
# Processing Record 33 of Set 14 | kalemie
# Processing Record 34 of Set 14 | puerto carreno
# Processing Record 35 of Set 14 | bignona
# Processing Record 36 of Set 14 | mezen
# Processing Record 37 of Set 14 | port augusta
# Processing Record 38 of Set 14 | eloy
# Processing Record 39 of Set 14 | pozo colorado
# Processing Record 40 of Set 14 | hirado
# Processing Record 41 of Set 14 | sobolevo
# Processing Record 42 of Set 14 | juneau
# Processing Record 43 of Set 14 | castlemaine
# Processing Record 44 of Set 14 | imbituba
# Processing Record 45 of Set 14 | ikwiriri
# Processing Record 46 of Set 14 | tautira
# Processing Record 47 of Set 14 | inta
# Processing Record 48 of Set 14 | aasiaat
# Processing Record 49 of Set 14 | smithers
# Processing Record 50 of Set 14 | roald
# Processing Record 1 of Set 15 | sungairaya
# Processing Record 2 of Set 15 | letychiv
# Processing Record 3 of Set 15 | amahai
# Processing Record 4 of Set 15 | sorochinsk
# Processing Record 5 of Set 15 | sovetskiy
# Processing Record 6 of Set 15 | puerto suarez
# Processing Record 7 of Set 15 | vila do maio
# Processing Record 8 of Set 15 | matara
# Processing Record 9 of Set 15 | pathein
# Processing Record 10 of Set 15 | concepcion del uruguay
# Processing Record 11 of Set 15 | portadown
# Processing Record 12 of Set 15 | mundra
# Processing Record 13 of Set 15 | fuerte olimpo
# Processing Record 14 of Set 15 | darhan
# Processing Record 15 of Set 15 | huoqiu
# Processing Record 16 of Set 15 | aksarayskiy
# Processing Record 17 of Set 15 | marienburg
# Processing Record 18 of Set 15 | dunedin
# Processing Record 19 of Set 15 | khingansk
# Processing Record 20 of Set 15 | oildale
# Processing Record 21 of Set 15 | bilma
# Processing Record 22 of Set 15 | komsomolskiy
# Processing Record 23 of Set 15 | pekalongan
# Processing Record 24 of Set 15 | galiwinku
# error
# Processing Record 25 of Set 15 | mukhen
# Processing Record 26 of Set 15 | franca
# Processing Record 27 of Set 15 | bundaberg
# Processing Record 28 of Set 15 | colquechaca
# Processing Record 29 of Set 15 | mayumba
# Processing Record 30 of Set 15 | carinhanha
# Processing Record 31 of Set 15 | oshawa
# Processing Record 32 of Set 15 | aswan
# Processing Record 33 of Set 15 | along
# Processing Record 34 of Set 15 | carbonia
# Processing Record 35 of Set 15 | alyangula
# Processing Record 36 of Set 15 | valley city
# Processing Record 37 of Set 15 | daniel flores
# Processing Record 38 of Set 15 | pilao arcado
# error
# Processing Record 39 of Set 15 | baykit
# Processing Record 40 of Set 15 | keuruu
# Processing Record 41 of Set 15 | bafq
# Processing Record 42 of Set 15 | znamenskoye
# Processing Record 43 of Set 15 | kyren
# Processing Record 44 of Set 15 | pitimbu
# Processing Record 45 of Set 15 | inongo
# Processing Record 46 of Set 15 | szczytno
# Processing Record 47 of Set 15 | shiyan
# Processing Record 48 of Set 15 | beihai
# Processing Record 49 of Set 15 | gat
# Processing Record 50 of Set 15 | mergui
# error
# Processing Record 1 of Set 16 | bosobolo
# Processing Record 2 of Set 16 | nemuro
# Processing Record 3 of Set 16 | terney
# Processing Record 4 of Set 16 | monchegorsk
# Processing Record 5 of Set 16 | anori
# Processing Record 6 of Set 16 | kijang
# Processing Record 7 of Set 16 | nauta
# Processing Record 8 of Set 16 | tarusa
# Processing Record 9 of Set 16 | ndjole
# Processing Record 10 of Set 16 | bandundu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# # Add data to new DataFrame

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Albany      US  42.6001  -73.9662     37.67        76         100
# 1      Qaanaaq      GL  77.4840  -69.3632      4.39        68          30
# 2      Rikitea      PF -23.1203 -134.9692     75.79        77           5
# 3       La Paz      BO -16.5000  -68.1500     44.58        93          40
# 4  East London      ZA -33.0153   27.9116     65.34       100          90
#
#    Wind Speed Weather Description                 Date
# 0        1.01     overcast clouds  2021-12-02 04:39:44
# 1        7.74    scattered clouds  2021-12-02 04:39:45
# 2       19.37          light rain  2021-12-02 04:39:47
# 3        4.61                 fog  2021-12-02 04:39:47
# 4        6.91                mist  2021-12-02 04:39:47

# %% [markdown]
# # Export DataFrame to CSV

# %%
city_data_df.to_csv('WeatherPy_Database.csv')
